# %% [markdown]
# ### Backtest Porfolio from Black–Litterman model for Asset Allocation - Backtrader

# %%
# necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import yfinance as yf
import pandas_datareader.data as web
import pyfolio as pf
import backtrader as bt
idx = pd.IndexSlice

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %%
# Read our 20 tickers weights
wt_min_vola = pd.read_csv('data/wt_min_vola_wts.csv',  index_col=[0])
print(wt_min_vola)
# Out:
#                    0
# ASIANPAINT  5.305046
# AXISBANK    4.450531
# BAJFINANCE  4.744928
# BHARTIARTL  5.178707
# HCLTECH     5.272667
# HDFC        4.897932
# HDFCBANK    5.088284
# HINDUNILVR  5.464385
# ICICIBANK   4.517027
# INFY        5.294840
# ITC         5.392489
# KOTAKBANK   4.943356
# LT          4.863501
# MARUTI      5.016308
# NESTLEIND   3.752084
# RELIANCE    5.011075
# SBIN        4.637817
# SUNPHARMA   5.397222
# TCS         5.382080
# WIPRO       5.389720

# %%
# plot the weights
wt_min_vola.plot.bar(figsize=(14,6), 
                    title = 'Asset Allocation Based on BL with Confidence Matrix', grid=True,legend=False);
plt.ylabel('Percentage')
plt.savefig('images/chart6', dpi=300)

# %%
# # data store path
# DATA_STORE = '../../../../machine-learning-for-trading-master/\
# machine-learning-for-trading-master/data/nse_asset.h5'

# %%
# with pd.HDFStore(DATA_STORE) as store:
#     print(store.info())

# %%
# # get the prices for top 20 companies
# with pd.HDFStore(DATA_STORE) as store:
#     prices = (store['/nse/nse500/prices'].loc[wt_min_vola.index])
# prices.head(2)

# %%
# # remove tickers where we have less than 10 years of data.
# min_obs = 2520
# nobs = prices.groupby(level='ticker').size()
# keep = nobs[nobs>min_obs].index

# prices = prices.loc[idx[keep,:], :]
# prices.info()

# %%
# date range for the backtesting
fromdate=datetime.datetime(2010, 1, 1)
todate=datetime.datetime(2020, 5, 29)

# %%
# # save the data as .csv file
# prices.to_csv('data/prices_all.csv')

# %%
# Read daily prices from csv
prices = pd.read_csv('data/prices_all.csv', index_col=['ticker','date'], parse_dates=True)
prices.head(2)
# Out:
#                           close  dividend       high        low       open  \
# ticker     date
# ASIANPAINT 2002-07-01  1.582765       0.0  22.466999  21.367001  21.367001
#            2002-07-02  1.599312       0.0  22.783001  21.370001  21.370001
#
#                        split    volume
# ticker     date
# ASIANPAINT 2002-07-01    0.0   87810.0
#            2002-07-02    0.0  588615.0

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 101013 entries, (ASIANPAINT, 2002-07-01 00:00:00) to (WIPRO, 2020-06-18 00:00:00)
# Data columns (total 7 columns):
# close       101002 non-null float64
# dividend    95926 non-null float64
# high        101002 non-null float64
# low         101002 non-null float64
# open        101002 non-null float64
# split       95926 non-null float64
# volume      101002 non-null float64
# dtypes: float64(7)
# memory usage: 5.7+ MB

# %%
# create a tuple list of ticker and weight
assets_param = [(ind, wt_min_vola.loc[ind][0]) for ind in wt_min_vola.index]
print(assets_param)
# Out:
# [('ASIANPAINT', 5.3050460949855), ('AXISBANK', 4.45053090038327), ('BAJFINANCE', 4.744928182806199), ('BHARTIARTL', 5.17870712426497), ('HCLTECH', 5.2726673958685195), ('HDFC', 4.897932406597451), ('HDFCBANK', 5.0882842942980995), ('HINDUNILVR', 5.46438474485979), ('ICICIBANK', 4.5170274183420105), ('INFY', 5.29483981039163), ('ITC', 5.392489026751269), ('KOTAKBANK', 4.94335575111937), ('LT', 4.86350114073377), ('MARUTI', 5.01630787685359), ('NESTLEIND', 3.75208389044434), ('RELIANCE', 5.01107450303204), ('SBIN', 4.637816734784139), ('SUNPHARMA', 5.39722219405121), ('TCS', 5.3820803779708895), ('WIPRO', 5.38972013146196)]

# %%
# define the strategy
class Strategy(bt.Strategy):
    # parameters for inputs    
    params = dict(
        assets = [],
        rebalance_months = [1,3,6,9]
    )
 
    # initialize
    def __init__(self):
        # create a dictionary of ticker:{'rebalanced': False, 'target_percent': target%}
        self.rebalance_dict = dict()
        for i, d in enumerate(self.datas):
            self.rebalance_dict[d] = dict()
            self.rebalance_dict[d]['rebalanced'] = False
            for asset in self.p.assets:
                if asset[0] == d._name:
                    self.rebalance_dict[d]['target_percent'] = asset[1]
 
    def next(self):
        # rebalance for the month in the list
        for i, d in enumerate(self.datas):
            dt = d.datetime.datetime()
            dname = d._name
            pos = self.getposition(d).size
 
            if dt.month in self.p.rebalance_months and self.rebalance_dict[d]['rebalanced'] == False:
                print('{} Sending Order: {} | Month {} | Rebalanced: {} | Pos: {}'.
                      format(dt, dname, dt.month,
                             self.rebalance_dict[d]['rebalanced'], pos ))
            
                self.order_target_percent(d, target=self.rebalance_dict[d]['target_percent']/100)
                self.rebalance_dict[d]['rebalanced'] = True
 
            # Reset the flage
            if dt.month not in self.p.rebalance_months:
                self.rebalance_dict[d]['rebalanced'] = False
                
    # notify the order if completed
    def notify_order(self, order):
        date = self.data.datetime.datetime().date()
 
        if order.status == order.Completed:
            print('{} >> Order Completed >> Stock: {},  Ref: {}, Size: {}, Price: {}'.
                  format(date, order.data._name, order.ref, order.size,
                         'NA' if not order.price else round(order.price,5)
                        ))

    # notify the trade if completed        
    def notify_trade(self, trade):
        date = self.data.datetime.datetime().date()
        if trade.isclosed:
            print('{} >> Notify Trade >> Stock: {}, Close Price: {}, Profit, Gross {}, Net {}'.
                  format(date, trade.data._name, trade.price, round(trade.pnl,2),round(trade.pnlcomm,2))
                 )

# %%
# starting cash
startcash = 500000

# 0.4% commission
commission = 0.004

#Create an instance of cerebro
cerebro = bt.Cerebro()

cerebro.broker.setcash(startcash)

# orders will not be checked to see if you can afford it before submitting them
cerebro.broker.set_checksubmit(False)

cerebro.broker.setcommission(commission=commission)

# %%
TICKERS = list(prices.index.get_level_values('ticker').unique())
print(TICKERS)
# Out:
# ['ASIANPAINT', 'AXISBANK', 'BAJFINANCE', 'BHARTIARTL', 'HCLTECH', 'HDFC', 'HDFCBANK', 'HINDUNILVR', 'ICICIBANK', 'INFY', 'ITC', 'KOTAKBANK', 'LT', 'MARUTI', 'NESTLEIND', 'RELIANCE', 'SBIN', 'SUNPHARMA', 'TCS', 'WIPRO']

# %%
# load the data
for ticker, data in prices.groupby(level=0):
    if ticker in TICKERS:
        print(f"Adding ticker: {ticker}")
        data = bt.feeds.PandasData(dataname=data.droplevel(level=0),
                                   name=str(ticker),
                                   fromdate=fromdate,
                                   todate=todate,
                                   plot=False)
        cerebro.adddata(data)
# Out:
# Adding ticker: ASIANPAINT
# Adding ticker: AXISBANK
# Adding ticker: BAJFINANCE
# Adding ticker: BHARTIARTL
# Adding ticker: HCLTECH
# Adding ticker: HDFC
# Adding ticker: HDFCBANK
# Adding ticker: HINDUNILVR
# Adding ticker: ICICIBANK
# Adding ticker: INFY
# Adding ticker: ITC
# Adding ticker: KOTAKBANK
# Adding ticker: LT
# Adding ticker: MARUTI
# Adding ticker: NESTLEIND
# Adding ticker: RELIANCE
# Adding ticker: SBIN
# Adding ticker: SUNPHARMA
# Adding ticker: TCS
# Adding ticker: WIPRO

# %%
#Add our strategy
cerebro.addstrategy(Strategy, assets=assets_param)

# add analyzers
cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='time_return')
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

# %%
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Run the strategy. 
results = cerebro.run(stdstats=True, tradehistory=False)
# Print out the final result
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 500000.00
# 2010-01-04 00:00:00 Sending Order: ASIANPAINT | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: AXISBANK | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: BAJFINANCE | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: BHARTIARTL | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: HCLTECH | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: HDFC | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: HDFCBANK | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: HINDUNILVR | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: ICICIBANK | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: INFY | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: ITC | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: KOTAKBANK | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: LT | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: MARUTI | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: NESTLEIND | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: RELIANCE | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: SBIN | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: SUNPHARMA | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: TCS | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-04 00:00:00 Sending Order: WIPRO | Month 1 | Rebalanced: False | Pos: 0
# 2010-01-05 >> Order Completed >> Stock: ASIANPAINT,  Ref: 1, Size: 235, Price: 112.66496
# 2010-01-05 >> Order Completed >> Stock: AXISBANK,  Ref: 2, Size: 158, Price: 140.71202
# 2010-01-05 >> Order Completed >> Stock: BAJFINANCE,  Ref: 3, Size: 1479, Price: 16.03158
# 2010-01-05 >> Order Completed >> Stock: BHARTIARTL,  Ref: 4, Size: 91, Price: 281.73782
# 2010-01-05 >> Order Completed >> Stock: HCLTECH,  Ref: 5, Size: 433, Price: 60.86014
# 2010-01-05 >> Order Completed >> Stock: HDFC,  Ref: 6, Size: 45, Price: 534.87
# 2010-01-05 >> Order Completed >> Stock: HDFCBANK,  Ref: 7, Size: 189, Price: 134.24521
# 2010-01-05 >> Order Completed >> Stock: HINDUNILVR,  Ref: 8, Size: 123, Price: 221.39713
# 2010-01-05 >> Order Completed >> Stock: ICICIBANK,  Ref: 9, Size: 264, Price: 85.31998
# 2010-01-05 >> Order Completed >> Stock: INFY,  Ref: 10, Size: 200, Price: 131.97508
# 2010-01-05 >> Order Completed >> Stock: ITC,  Ref: 11, Size: 412, Price: 65.32603
# 2010-01-05 >> Order Completed >> Stock: KOTAKBANK,  Ref: 12, Size: 122, Price: 202.42604
# 2010-01-05 >> Order Completed >> Stock: LT,  Ref: 13, Size: 40, Price: 607.6308
# 2010-03-02 00:00:00 Sending Order: ASIANPAINT | Month 3 | Rebalanced: False | Pos: 235
# 2010-03-02 00:00:00 Sending Order: AXISBANK | Month 3 | Rebalanced: False | Pos: 158
# 2010-03-02 00:00:00 Sending Order: BAJFINANCE | Month 3 | Rebalanced: False | Pos: 1479
# 2010-03-02 00:00:00 Sending Order: BHARTIARTL | Month 3 | Rebalanced: False | Pos: 91
# 2010-03-02 00:00:00 Sending Order: HCLTECH | Month 3 | Rebalanced: False | Pos: 433
# 2010-03-02 00:00:00 Sending Order: HDFC | Month 3 | Rebalanced: False | Pos: 45
# 2010-03-02 00:00:00 Sending Order: HDFCBANK | Month 3 | Rebalanced: False | Pos: 189
# 2010-03-02 00:00:00 Sending Order: HINDUNILVR | Month 3 | Rebalanced: False | Pos: 123
# 2010-03-02 00:00:00 Sending Order: ICICIBANK | Month 3 | Rebalanced: False | Pos: 264
# 2010-03-02 00:00:00 Sending Order: INFY | Month 3 | Rebalanced: False | Pos: 200
# 2010-03-02 00:00:00 Sending Order: ITC | Month 3 | Rebalanced: False | Pos: 412
# 2010-03-02 00:00:00 Sending Order: KOTAKBANK | Month 3 | Rebalanced: False | Pos: 122
# 2010-03-02 00:00:00 Sending Order: LT | Month 3 | Rebalanced: False | Pos: 40
# 2010-03-02 00:00:00 Sending Order: MARUTI | Month 3 | Rebalanced: False | Pos: 0
# 2010-03-02 00:00:00 Sending Order: NESTLEIND | Month 3 | Rebalanced: False | Pos: 0
# 2010-03-02 00:00:00 Sending Order: RELIANCE | Month 3 | Rebalanced: False | Pos: 0
# 2010-03-02 00:00:00 Sending Order: SBIN | Month 3 | Rebalanced: False | Pos: 0
# 2010-03-02 00:00:00 Sending Order: SUNPHARMA | Month 3 | Rebalanced: False | Pos: 0
# 2010-03-02 00:00:00 Sending Order: TCS | Month 3 | Rebalanced: False | Pos: 0
# 2010-03-02 00:00:00 Sending Order: WIPRO | Month 3 | Rebalanced: False | Pos: 0
# 2010-03-03 >> Order Completed >> Stock: ASIANPAINT,  Ref: 21, Size: -83, Price: 117.78593
# 2010-03-03 >> Order Completed >> Stock: AXISBANK,  Ref: 22, Size: -66, Price: 163.81651
# 2010-03-03 >> Order Completed >> Stock: BAJFINANCE,  Ref: 23, Size: -393, Price: 14.70226
# 2010-03-03 >> Order Completed >> Stock: BHARTIARTL,  Ref: 24, Size: -21, Price: 251.41484
# 2010-03-03 >> Order Completed >> Stock: HCLTECH,  Ref: 25, Size: -140, Price: 60.53222
# 2010-03-03 >> Order Completed >> Stock: HDFC,  Ref: 26, Size: -12, Price: 512.06
# 2010-03-03 >> Order Completed >> Stock: HDFCBANK,  Ref: 27, Size: -64, Price: 137.3343
# 2010-03-03 >> Order Completed >> Stock: HINDUNILVR,  Ref: 28, Size: -29, Price: 196.09583
# 2010-03-03 >> Order Completed >> Stock: ICICIBANK,  Ref: 29, Size: -89, Price: 87.01255
# 2010-03-03 >> Order Completed >> Stock: INFY,  Ref: 30, Size: -66, Price: 133.40964
# 2010-03-03 >> Order Completed >> Stock: ITC,  Ref: 31, Size: -120, Price: 62.31278
# 2010-03-03 >> Order Completed >> Stock: KOTAKBANK,  Ref: 32, Size: -31, Price: 184.30832
# 2010-03-03 >> Order Completed >> Stock: LT,  Ref: 33, Size: -11, Price: 569.55072
# 2010-03-03 >> Order Completed >> Stock: MARUTI,  Ref: 34, Size: 12, Price: 1373.45886
# 2010-03-03 >> Order Completed >> Stock: NESTLEIND,  Ref: 35, Size: 5, Price: 2272.49927
# 2010-03-03 >> Order Completed >> Stock: RELIANCE,  Ref: 36, Size: 40, Price: 419.62994
# 2010-03-03 >> Order Completed >> Stock: SBIN,  Ref: 37, Size: 179, Price: 86.89122
# 2010-03-03 >> Order Completed >> Stock: SUNPHARMA,  Ref: 38, Size: 134, Price: 134.49582
# 2010-03-03 >> Order Completed >> Stock: TCS,  Ref: 39, Size: 63, Price: 285.60373
# 2010-03-03 >> Order Completed >> Stock: WIPRO,  Ref: 40, Size: 165, Price: 109.29459
# 2010-06-01 00:00:00 Sending Order: ASIANPAINT | Month 6 | Rebalanced: False | Pos: 152
# 2010-06-01 00:00:00 Sending Order: AXISBANK | Month 6 | Rebalanced: False | Pos: 92
# 2010-06-01 00:00:00 Sending Order: BAJFINANCE | Month 6 | Rebalanced: False | Pos: 1086
# 2010-06-01 00:00:00 Sending Order: BHARTIARTL | Month 6 | Rebalanced: False | Pos: 70
# 2010-06-01 00:00:00 Sending Order: HCLTECH | Month 6 | Rebalanced: False | Pos: 293
# 2010-06-01 00:00:00 Sending Order: HDFC | Month 6 | Rebalanced: False | Pos: 33
# 2010-06-01 00:00:00 Sending Order: HDFCBANK | Month 6 | Rebalanced: False | Pos: 125
# 2010-06-01 00:00:00 Sending Order: HINDUNILVR | Month 6 | Rebalanced: False | Pos: 94
# 2010-06-01 00:00:00 Sending Order: ICICIBANK | Month 6 | Rebalanced: False | Pos: 175
# 2010-06-01 00:00:00 Sending Order: INFY | Month 6 | Rebalanced: False | Pos: 134
# 2010-06-01 00:00:00 Sending Order: ITC | Month 6 | Rebalanced: False | Pos: 292
# 2010-06-01 00:00:00 Sending Order: KOTAKBANK | Month 6 | Rebalanced: False | Pos: 91
# 2010-06-01 00:00:00 Sending Order: LT | Month 6 | Rebalanced: False | Pos: 29
# 2010-06-01 00:00:00 Sending Order: MARUTI | Month 6 | Rebalanced: False | Pos: 12
# 2010-06-01 00:00:00 Sending Order: NESTLEIND | Month 6 | Rebalanced: False | Pos: 5
# 2010-06-01 00:00:00 Sending Order: RELIANCE | Month 6 | Rebalanced: False | Pos: 40
# 2010-06-01 00:00:00 Sending Order: SBIN | Month 6 | Rebalanced: False | Pos: 179
# 2010-06-01 00:00:00 Sending Order: SUNPHARMA | Month 6 | Rebalanced: False | Pos: 134
# 2010-06-01 00:00:00 Sending Order: TCS | Month 6 | Rebalanced: False | Pos: 63
# 2010-06-01 00:00:00 Sending Order: WIPRO | Month 6 | Rebalanced: False | Pos: 165
# 2010-06-02 >> Order Completed >> Stock: ASIANPAINT,  Ref: 41, Size: -7, Price: 130.84351
# 2010-06-02 >> Order Completed >> Stock: AXISBANK,  Ref: 42, Size: -2, Price: 176.38577
# 2010-06-02 >> Order Completed >> Stock: BAJFINANCE,  Ref: 43, Size: -317, Price: 21.95644
# 2010-06-02 >> Order Completed >> Stock: BHARTIARTL,  Ref: 44, Size: 12, Price: 222.65244
# 2010-06-02 >> Order Completed >> Stock: HCLTECH,  Ref: 45, Size: 13, Price: 61.17985
# 2010-06-02 >> Order Completed >> Stock: HDFCBANK,  Ref: 46, Size: -1, Price: 146.00352
# 2010-06-02 >> Order Completed >> Stock: HINDUNILVR,  Ref: 47, Size: 5, Price: 195.55215
# 2010-06-02 >> Order Completed >> Stock: ICICIBANK,  Ref: 48, Size: 22, Price: 81.2712
# 2010-06-02 >> Order Completed >> Stock: INFY,  Ref: 49, Size: 1, Price: 139.16031
# 2010-06-02 >> Order Completed >> Stock: ITC,  Ref: 50, Size: -28, Price: 72.88493
# 2010-06-02 >> Order Completed >> Stock: KOTAKBANK,  Ref: 51, Size: 3, Price: 185.87085
# 2010-06-02 >> Order Completed >> Stock: LT,  Ref: 52, Size: 1, Price: 572.49713
# 2010-06-02 >> Order Completed >> Stock: MARUTI,  Ref: 53, Size: 3, Price: 1157.82849
# 2010-06-02 >> Order Completed >> Stock: SBIN,  Ref: 54, Size: -8, Price: 96.6447
# 2010-06-02 >> Order Completed >> Stock: SUNPHARMA,  Ref: 55, Size: -2, Price: 145.7179
# 2010-06-02 >> Order Completed >> Stock: TCS,  Ref: 56, Size: 6, Price: 276.62259
# 2010-06-02 >> Order Completed >> Stock: WIPRO,  Ref: 57, Size: 21, Price: 102.60033
# 2010-09-01 00:00:00 Sending Order: ASIANPAINT | Month 9 | Rebalanced: False | Pos: 145
# 2010-09-01 00:00:00 Sending Order: AXISBANK | Month 9 | Rebalanced: False | Pos: 90
# 2010-09-01 00:00:00 Sending Order: BAJFINANCE | Month 9 | Rebalanced: False | Pos: 769
# 2010-09-01 00:00:00 Sending Order: BHARTIARTL | Month 9 | Rebalanced: False | Pos: 82
# 2010-09-01 00:00:00 Sending Order: HCLTECH | Month 9 | Rebalanced: False | Pos: 306
# 2010-09-01 00:00:00 Sending Order: HDFC | Month 9 | Rebalanced: False | Pos: 33
# 2010-09-01 00:00:00 Sending Order: HDFCBANK | Month 9 | Rebalanced: False | Pos: 124
# 2010-09-01 00:00:00 Sending Order: HINDUNILVR | Month 9 | Rebalanced: False | Pos: 99
# 2010-09-01 00:00:00 Sending Order: ICICIBANK | Month 9 | Rebalanced: False | Pos: 197
# 2010-09-01 00:00:00 Sending Order: INFY | Month 9 | Rebalanced: False | Pos: 135
# 2010-09-01 00:00:00 Sending Order: ITC | Month 9 | Rebalanced: False | Pos: 264
# 2010-09-01 00:00:00 Sending Order: KOTAKBANK | Month 9 | Rebalanced: False | Pos: 94
# 2010-09-01 00:00:00 Sending Order: LT | Month 9 | Rebalanced: False | Pos: 30
# 2010-09-01 00:00:00 Sending Order: MARUTI | Month 9 | Rebalanced: False | Pos: 15
# 2010-09-01 00:00:00 Sending Order: NESTLEIND | Month 9 | Rebalanced: False | Pos: 5
# 2010-09-01 00:00:00 Sending Order: RELIANCE | Month 9 | Rebalanced: False | Pos: 40
# 2010-09-01 00:00:00 Sending Order: SBIN | Month 9 | Rebalanced: False | Pos: 171
# 2010-09-01 00:00:00 Sending Order: SUNPHARMA | Month 9 | Rebalanced: False | Pos: 132
# 2010-09-01 00:00:00 Sending Order: TCS | Month 9 | Rebalanced: False | Pos: 69
# 2010-09-01 00:00:00 Sending Order: WIPRO | Month 9 | Rebalanced: False | Pos: 186
# 2010-09-02 >> Order Completed >> Stock: ASIANPAINT,  Ref: 58, Size: -24, Price: 187.18024
# 2010-09-02 >> Order Completed >> Stock: AXISBANK,  Ref: 59, Size: 3, Price: 202.11896
# 2010-09-02 >> Order Completed >> Stock: BAJFINANCE,  Ref: 60, Size: -167, Price: 33.42771
# 2010-09-02 >> Order Completed >> Stock: BHARTIARTL,  Ref: 61, Size: -7, Price: 293.53497
# 2010-09-02 >> Order Completed >> Stock: HCLTECH,  Ref: 62, Size: 39, Price: 64.72541
# 2010-09-02 >> Order Completed >> Stock: HDFCBANK,  Ref: 63, Size: -4, Price: 180.68166
# 2010-09-02 >> Order Completed >> Stock: HINDUNILVR,  Ref: 64, Size: 3, Price: 225.89915
# 2010-09-02 >> Order Completed >> Stock: ICICIBANK,  Ref: 65, Size: -14, Price: 104.89939
# 2010-09-02 >> Order Completed >> Stock: INFY,  Ref: 66, Size: 17, Price: 147.2097
# 2010-09-02 >> Order Completed >> Stock: ITC,  Ref: 67, Size: -4, Price: 88.14438
# 2010-09-02 >> Order Completed >> Stock: KOTAKBANK,  Ref: 68, Size: 8, Price: 205.10924
# 2010-09-02 >> Order Completed >> Stock: MARUTI,  Ref: 69, Size: 3, Price: 1178.01257
# 2010-09-02 >> Order Completed >> Stock: RELIANCE,  Ref: 70, Size: 12, Price: 405.06113
# 2010-09-02 >> Order Completed >> Stock: SBIN,  Ref: 71, Size: -23, Price: 133.0927
# 2010-09-02 >> Order Completed >> Stock: SUNPHARMA,  Ref: 72, Size: 18, Price: 151.75587
# 2010-09-02 >> Order Completed >> Stock: WIPRO,  Ref: 73, Size: 18, Price: 111.91144
# 2011-01-03 00:00:00 Sending Order: ASIANPAINT | Month 1 | Rebalanced: False | Pos: 121
# 2011-01-03 00:00:00 Sending Order: AXISBANK | Month 1 | Rebalanced: False | Pos: 93
# 2011-01-03 00:00:00 Sending Order: BAJFINANCE | Month 1 | Rebalanced: False | Pos: 602
# 2011-01-03 00:00:00 Sending Order: BHARTIARTL | Month 1 | Rebalanced: False | Pos: 75
# 2011-01-03 00:00:00 Sending Order: HCLTECH | Month 1 | Rebalanced: False | Pos: 345
# 2011-01-03 00:00:00 Sending Order: HDFC | Month 1 | Rebalanced: False | Pos: 33
# 2011-01-03 00:00:00 Sending Order: HDFCBANK | Month 1 | Rebalanced: False | Pos: 120
# 2011-01-03 00:00:00 Sending Order: HINDUNILVR | Month 1 | Rebalanced: False | Pos: 102
# 2011-01-03 00:00:00 Sending Order: ICICIBANK | Month 1 | Rebalanced: False | Pos: 183
# 2011-01-03 00:00:00 Sending Order: INFY | Month 1 | Rebalanced: False | Pos: 152
# 2011-01-03 00:00:00 Sending Order: ITC | Month 1 | Rebalanced: False | Pos: 260
# 2011-01-03 00:00:00 Sending Order: KOTAKBANK | Month 1 | Rebalanced: False | Pos: 102
# 2011-01-03 00:00:00 Sending Order: LT | Month 1 | Rebalanced: False | Pos: 30
# 2011-01-03 00:00:00 Sending Order: MARUTI | Month 1 | Rebalanced: False | Pos: 18
# 2011-01-03 00:00:00 Sending Order: NESTLEIND | Month 1 | Rebalanced: False | Pos: 5
# 2011-01-03 00:00:00 Sending Order: RELIANCE | Month 1 | Rebalanced: False | Pos: 52
# 2011-01-03 00:00:00 Sending Order: SBIN | Month 1 | Rebalanced: False | Pos: 148
# 2011-01-03 00:00:00 Sending Order: SUNPHARMA | Month 1 | Rebalanced: False | Pos: 150
# 2011-01-03 00:00:00 Sending Order: TCS | Month 1 | Rebalanced: False | Pos: 69
# 2011-01-03 00:00:00 Sending Order: WIPRO | Month 1 | Rebalanced: False | Pos: 204
# 2011-01-04 >> Order Completed >> Stock: ASIANPAINT,  Ref: 74, Size: 8, Price: 202.97585
# 2011-01-04 >> Order Completed >> Stock: AXISBANK,  Ref: 75, Size: 15, Price: 204.14151
# 2011-01-04 >> Order Completed >> Stock: HCLTECH,  Ref: 78, Size: -9, Price: 77.97363
# 2011-01-04 >> Order Completed >> Stock: HDFCBANK,  Ref: 79, Size: 5, Price: 200.96288
# 2011-01-04 >> Order Completed >> Stock: ICICIBANK,  Ref: 80, Size: 2, Price: 120.69791
# 2011-01-04 >> Order Completed >> Stock: INFY,  Ref: 81, Size: -12, Price: 188.37686
# 2011-01-04 >> Order Completed >> Stock: ITC,  Ref: 82, Size: 23, Price: 94.43793
# 2011-01-04 >> Order Completed >> Stock: KOTAKBANK,  Ref: 83, Size: 6, Price: 225.91669
# 2011-01-04 >> Order Completed >> Stock: RELIANCE,  Ref: 85, Size: 2, Price: 456.72125
# 2011-01-04 >> Order Completed >> Stock: SUNPHARMA,  Ref: 87, Size: -33, Price: 229.18939
# 2011-01-04 >> Order Completed >> Stock: TCS,  Ref: 88, Size: -8, Price: 441.586
# 2011-01-04 >> Order Completed >> Stock: WIPRO,  Ref: 89, Size: -4, Price: 133.9586
# 2011-03-01 00:00:00 Sending Order: ASIANPAINT | Month 3 | Rebalanced: False | Pos: 129
# 2011-03-01 00:00:00 Sending Order: AXISBANK | Month 3 | Rebalanced: False | Pos: 108
# 2011-03-01 00:00:00 Sending Order: BAJFINANCE | Month 3 | Rebalanced: False | Pos: 602
# 2011-03-01 00:00:00 Sending Order: BHARTIARTL | Month 3 | Rebalanced: False | Pos: 75
# 2011-03-01 00:00:00 Sending Order: HCLTECH | Month 3 | Rebalanced: False | Pos: 336
# 2011-03-01 00:00:00 Sending Order: HDFC | Month 3 | Rebalanced: False | Pos: 33
# 2011-03-01 00:00:00 Sending Order: HDFCBANK | Month 3 | Rebalanced: False | Pos: 125
# 2011-03-01 00:00:00 Sending Order: HINDUNILVR | Month 3 | Rebalanced: False | Pos: 102
# 2011-03-01 00:00:00 Sending Order: ICICIBANK | Month 3 | Rebalanced: False | Pos: 185
# 2011-03-01 00:00:00 Sending Order: INFY | Month 3 | Rebalanced: False | Pos: 140
# 2011-03-01 00:00:00 Sending Order: ITC | Month 3 | Rebalanced: False | Pos: 283
# 2011-03-01 00:00:00 Sending Order: KOTAKBANK | Month 3 | Rebalanced: False | Pos: 108
# 2011-03-01 00:00:00 Sending Order: LT | Month 3 | Rebalanced: False | Pos: 30
# 2011-03-01 00:00:00 Sending Order: MARUTI | Month 3 | Rebalanced: False | Pos: 18
# 2011-03-01 00:00:00 Sending Order: NESTLEIND | Month 3 | Rebalanced: False | Pos: 5
# 2011-03-01 00:00:00 Sending Order: RELIANCE | Month 3 | Rebalanced: False | Pos: 54
# 2011-03-01 00:00:00 Sending Order: SBIN | Month 3 | Rebalanced: False | Pos: 148
# 2011-03-01 00:00:00 Sending Order: SUNPHARMA | Month 3 | Rebalanced: False | Pos: 117
# 2011-03-01 00:00:00 Sending Order: TCS | Month 3 | Rebalanced: False | Pos: 61
# 2011-03-01 00:00:00 Sending Order: WIPRO | Month 3 | Rebalanced: False | Pos: 200
# 2011-03-03 >> Order Completed >> Stock: ASIANPAINT,  Ref: 90, Size: 7, Price: 178.84445
# 2011-03-03 >> Order Completed >> Stock: AXISBANK,  Ref: 91, Size: -1, Price: 192.37199
# 2011-03-03 >> Order Completed >> Stock: BAJFINANCE,  Ref: 92, Size: 63, Price: 32.8847
# 2011-03-03 >> Order Completed >> Stock: BHARTIARTL,  Ref: 93, Size: 6, Price: 293.49139
# 2011-03-03 >> Order Completed >> Stock: HCLTECH,  Ref: 94, Size: -38, Price: 81.79087
# 2011-03-03 >> Order Completed >> Stock: HDFC,  Ref: 95, Size: 1, Price: 650.75
# 2011-03-03 >> Order Completed >> Stock: HDFCBANK,  Ref: 96, Size: 5, Price: 179.81993
# 2011-03-03 >> Order Completed >> Stock: ICICIBANK,  Ref: 97, Size: 7, Price: 108.18887
# 2011-03-03 >> Order Completed >> Stock: INFY,  Ref: 98, Size: 5, Price: 167.89873
# 2011-03-03 >> Order Completed >> Stock: ITC,  Ref: 99, Size: -17, Price: 93.7896
# 2011-03-03 >> Order Completed >> Stock: KOTAKBANK,  Ref: 100, Size: 3, Price: 204.8127
# 2011-03-03 >> Order Completed >> Stock: LT,  Ref: 101, Size: 8, Price: 588.07794
# 2011-03-03 >> Order Completed >> Stock: MARUTI,  Ref: 102, Size: 1, Price: 1194.67261
# 2011-03-03 >> Order Completed >> Stock: SUNPHARMA,  Ref: 104, Size: 1, Price: 209.85905
# 2011-03-03 >> Order Completed >> Stock: TCS,  Ref: 105, Size: -3, Price: 430.24072
# 2011-06-01 00:00:00 Sending Order: ASIANPAINT | Month 6 | Rebalanced: False | Pos: 136
# 2011-06-01 00:00:00 Sending Order: AXISBANK | Month 6 | Rebalanced: False | Pos: 107
# 2011-06-01 00:00:00 Sending Order: BAJFINANCE | Month 6 | Rebalanced: False | Pos: 665
# 2011-06-01 00:00:00 Sending Order: BHARTIARTL | Month 6 | Rebalanced: False | Pos: 81
# 2011-06-01 00:00:00 Sending Order: HCLTECH | Month 6 | Rebalanced: False | Pos: 298
# 2011-06-01 00:00:00 Sending Order: HDFC | Month 6 | Rebalanced: False | Pos: 34
# 2011-06-01 00:00:00 Sending Order: HDFCBANK | Month 6 | Rebalanced: False | Pos: 130
# 2011-06-01 00:00:00 Sending Order: HINDUNILVR | Month 6 | Rebalanced: False | Pos: 102
# 2011-06-01 00:00:00 Sending Order: ICICIBANK | Month 6 | Rebalanced: False | Pos: 192
# 2011-06-01 00:00:00 Sending Order: INFY | Month 6 | Rebalanced: False | Pos: 145
# 2011-06-01 00:00:00 Sending Order: ITC | Month 6 | Rebalanced: False | Pos: 266
# 2011-06-01 00:00:00 Sending Order: KOTAKBANK | Month 6 | Rebalanced: False | Pos: 111
# 2011-06-01 00:00:00 Sending Order: LT | Month 6 | Rebalanced: False | Pos: 38
# 2011-06-01 00:00:00 Sending Order: MARUTI | Month 6 | Rebalanced: False | Pos: 19
# 2011-06-01 00:00:00 Sending Order: NESTLEIND | Month 6 | Rebalanced: False | Pos: 5
# 2011-06-01 00:00:00 Sending Order: RELIANCE | Month 6 | Rebalanced: False | Pos: 54
# 2011-06-01 00:00:00 Sending Order: SBIN | Month 6 | Rebalanced: False | Pos: 148
# 2011-06-01 00:00:00 Sending Order: SUNPHARMA | Month 6 | Rebalanced: False | Pos: 118
# 2011-06-01 00:00:00 Sending Order: TCS | Month 6 | Rebalanced: False | Pos: 58
# 2011-06-01 00:00:00 Sending Order: WIPRO | Month 6 | Rebalanced: False | Pos: 200
# 2011-06-02 >> Order Completed >> Stock: ASIANPAINT,  Ref: 106, Size: -20, Price: 223.79208
# 2011-06-02 >> Order Completed >> Stock: AXISBANK,  Ref: 107, Size: 6, Price: 190.79726
# 2011-06-02 >> Order Completed >> Stock: BAJFINANCE,  Ref: 108, Size: 20, Price: 33.63801
# 2011-06-02 >> Order Completed >> Stock: BHARTIARTL,  Ref: 109, Size: -5, Price: 331.74283
# 2011-06-02 >> Order Completed >> Stock: HCLTECH,  Ref: 110, Size: -17, Price: 91.16101
# 2011-06-02 >> Order Completed >> Stock: HDFCBANK,  Ref: 111, Size: -7, Price: 201.61018
# 2011-06-02 >> Order Completed >> Stock: HINDUNILVR,  Ref: 112, Size: -2, Price: 265.80994
# 2011-06-02 >> Order Completed >> Stock: INFY,  Ref: 113, Size: 13, Price: 162.46725
# 2011-06-02 >> Order Completed >> Stock: ITC,  Ref: 114, Size: -15, Price: 104.72994
# 2011-06-02 >> Order Completed >> Stock: MARUTI,  Ref: 115, Size: 2, Price: 1157.04858
# 2011-06-02 >> Order Completed >> Stock: RELIANCE,  Ref: 116, Size: 4, Price: 416.6825
# 2011-06-02 >> Order Completed >> Stock: WIPRO,  Ref: 118, Size: 8, Price: 125.82358
# 2011-09-02 00:00:00 Sending Order: ASIANPAINT | Month 9 | Rebalanced: False | Pos: 116
# 2011-09-02 00:00:00 Sending Order: AXISBANK | Month 9 | Rebalanced: False | Pos: 113
# 2011-09-02 00:00:00 Sending Order: BAJFINANCE | Month 9 | Rebalanced: False | Pos: 685
# 2011-09-02 00:00:00 Sending Order: BHARTIARTL | Month 9 | Rebalanced: False | Pos: 76
# 2011-09-02 00:00:00 Sending Order: HCLTECH | Month 9 | Rebalanced: False | Pos: 281
# 2011-09-02 00:00:00 Sending Order: HDFC | Month 9 | Rebalanced: False | Pos: 34
# 2011-09-02 00:00:00 Sending Order: HDFCBANK | Month 9 | Rebalanced: False | Pos: 123
# 2011-09-02 00:00:00 Sending Order: HINDUNILVR | Month 9 | Rebalanced: False | Pos: 100
# 2011-09-02 00:00:00 Sending Order: ICICIBANK | Month 9 | Rebalanced: False | Pos: 192
# 2011-09-02 00:00:00 Sending Order: INFY | Month 9 | Rebalanced: False | Pos: 158
# 2011-09-02 00:00:00 Sending Order: ITC | Month 9 | Rebalanced: False | Pos: 251
# 2011-09-02 00:00:00 Sending Order: KOTAKBANK | Month 9 | Rebalanced: False | Pos: 111
# 2011-09-02 00:00:00 Sending Order: LT | Month 9 | Rebalanced: False | Pos: 38
# 2011-09-02 00:00:00 Sending Order: MARUTI | Month 9 | Rebalanced: False | Pos: 21
# 2011-09-02 00:00:00 Sending Order: NESTLEIND | Month 9 | Rebalanced: False | Pos: 5
# 2011-09-02 00:00:00 Sending Order: RELIANCE | Month 9 | Rebalanced: False | Pos: 58
# 2011-09-02 00:00:00 Sending Order: SBIN | Month 9 | Rebalanced: False | Pos: 148
# 2011-09-02 00:00:00 Sending Order: SUNPHARMA | Month 9 | Rebalanced: False | Pos: 118
# 2011-09-02 00:00:00 Sending Order: TCS | Month 9 | Rebalanced: False | Pos: 58
# 2011-09-02 00:00:00 Sending Order: WIPRO | Month 9 | Rebalanced: False | Pos: 208
# 2011-09-05 >> Order Completed >> Stock: ASIANPAINT,  Ref: 119, Size: -16, Price: 248.42271
# 2011-09-05 >> Order Completed >> Stock: AXISBANK,  Ref: 120, Size: 8, Price: 170.87547
# 2011-09-05 >> Order Completed >> Stock: BAJFINANCE,  Ref: 121, Size: -135, Price: 40.33449
# 2011-09-05 >> Order Completed >> Stock: BHARTIARTL,  Ref: 122, Size: -8, Price: 356.19534
# 2011-09-05 >> Order Completed >> Stock: HCLTECH,  Ref: 123, Size: 69, Price: 70.35558
# 2011-09-05 >> Order Completed >> Stock: HDFCBANK,  Ref: 124, Size: -11, Price: 213.41861
# 2011-09-05 >> Order Completed >> Stock: HINDUNILVR,  Ref: 125, Size: -7, Price: 276.87292
# 2011-09-05 >> Order Completed >> Stock: ICICIBANK,  Ref: 126, Size: 17, Price: 100.67593
# 2011-09-05 >> Order Completed >> Stock: INFY,  Ref: 127, Size: 26, Price: 134.01636
# 2011-09-05 >> Order Completed >> Stock: ITC,  Ref: 128, Size: -26, Price: 112.22589
# 2011-09-05 >> Order Completed >> Stock: KOTAKBANK,  Ref: 129, Size: -5, Price: 219.42738
# 2011-09-05 >> Order Completed >> Stock: MARUTI,  Ref: 130, Size: 2, Price: 1005.14685
# 2011-09-05 >> Order Completed >> Stock: RELIANCE,  Ref: 131, Size: 8, Price: 354.47504
# 2011-09-05 >> Order Completed >> Stock: SUNPHARMA,  Ref: 133, Size: -13, Price: 241.39827
# 2011-09-05 >> Order Completed >> Stock: TCS,  Ref: 134, Size: 5, Price: 398.52487
# 2012-01-02 00:00:00 Sending Order: ASIANPAINT | Month 1 | Rebalanced: False | Pos: 100
# 2012-01-02 00:00:00 Sending Order: AXISBANK | Month 1 | Rebalanced: False | Pos: 121
# 2012-01-02 00:00:00 Sending Order: BAJFINANCE | Month 1 | Rebalanced: False | Pos: 550
# 2012-01-02 00:00:00 Sending Order: BHARTIARTL | Month 1 | Rebalanced: False | Pos: 68
# 2012-01-02 00:00:00 Sending Order: HCLTECH | Month 1 | Rebalanced: False | Pos: 350
# 2012-01-02 00:00:00 Sending Order: HDFC | Month 1 | Rebalanced: False | Pos: 34
# 2012-01-02 00:00:00 Sending Order: HDFCBANK | Month 1 | Rebalanced: False | Pos: 112
# 2012-01-02 00:00:00 Sending Order: HINDUNILVR | Month 1 | Rebalanced: False | Pos: 93
# 2012-01-02 00:00:00 Sending Order: ICICIBANK | Month 1 | Rebalanced: False | Pos: 209
# 2012-01-02 00:00:00 Sending Order: INFY | Month 1 | Rebalanced: False | Pos: 184
# 2012-01-02 00:00:00 Sending Order: ITC | Month 1 | Rebalanced: False | Pos: 225
# 2012-01-02 00:00:00 Sending Order: KOTAKBANK | Month 1 | Rebalanced: False | Pos: 106
# 2012-01-02 00:00:00 Sending Order: LT | Month 1 | Rebalanced: False | Pos: 38
# 2012-01-02 00:00:00 Sending Order: MARUTI | Month 1 | Rebalanced: False | Pos: 23
# 2012-01-02 00:00:00 Sending Order: NESTLEIND | Month 1 | Rebalanced: False | Pos: 5
# 2012-01-02 00:00:00 Sending Order: RELIANCE | Month 1 | Rebalanced: False | Pos: 66
# 2012-01-02 00:00:00 Sending Order: SBIN | Month 1 | Rebalanced: False | Pos: 148
# 2012-01-02 00:00:00 Sending Order: SUNPHARMA | Month 1 | Rebalanced: False | Pos: 105
# 2012-01-02 00:00:00 Sending Order: TCS | Month 1 | Rebalanced: False | Pos: 63
# 2012-01-02 00:00:00 Sending Order: WIPRO | Month 1 | Rebalanced: False | Pos: 208
# 2012-01-03 >> Order Completed >> Stock: ASIANPAINT,  Ref: 136, Size: 15, Price: 203.72562
# 2012-01-03 >> Order Completed >> Stock: BAJFINANCE,  Ref: 138, Size: -7, Price: 38.7021
# 2012-01-03 >> Order Completed >> Stock: HCLTECH,  Ref: 140, Size: -21, Price: 71.13534
# 2012-01-03 >> Order Completed >> Stock: HDFCBANK,  Ref: 141, Size: 4, Price: 192.67712
# 2012-01-03 >> Order Completed >> Stock: HINDUNILVR,  Ref: 142, Size: -24, Price: 351.3851
# 2012-01-03 >> Order Completed >> Stock: ICICIBANK,  Ref: 143, Size: 43, Price: 79.0459
# 2012-01-03 >> Order Completed >> Stock: INFY,  Ref: 144, Size: -45, Price: 169.78627
# 2012-01-03 >> Order Completed >> Stock: ITC,  Ref: 145, Size: -7, Price: 109.68569
# 2012-01-03 >> Order Completed >> Stock: KOTAKBANK,  Ref: 146, Size: -1, Price: 208.87827
# 2012-01-03 >> Order Completed >> Stock: LT,  Ref: 147, Size: 19, Price: 375.83139
# 2012-01-03 >> Order Completed >> Stock: MARUTI,  Ref: 148, Size: 2, Price: 874.67676
# 2012-01-03 >> Order Completed >> Stock: RELIANCE,  Ref: 149, Size: 5, Price: 310.94952
# 2012-01-03 >> Order Completed >> Stock: SUNPHARMA,  Ref: 151, Size: -3, Price: 236.26926
# 2012-01-03 >> Order Completed >> Stock: TCS,  Ref: 152, Size: -11, Price: 462.11334
# 2012-03-01 00:00:00 Sending Order: ASIANPAINT | Month 3 | Rebalanced: False | Pos: 115
# 2012-03-01 00:00:00 Sending Order: AXISBANK | Month 3 | Rebalanced: False | Pos: 121
# 2012-03-01 00:00:00 Sending Order: BAJFINANCE | Month 3 | Rebalanced: False | Pos: 543
# 2012-03-01 00:00:00 Sending Order: BHARTIARTL | Month 3 | Rebalanced: False | Pos: 68
# 2012-03-01 00:00:00 Sending Order: HCLTECH | Month 3 | Rebalanced: False | Pos: 329
# 2012-03-01 00:00:00 Sending Order: HDFC | Month 3 | Rebalanced: False | Pos: 34
# 2012-03-01 00:00:00 Sending Order: HDFCBANK | Month 3 | Rebalanced: False | Pos: 116
# 2012-03-01 00:00:00 Sending Order: HINDUNILVR | Month 3 | Rebalanced: False | Pos: 69
# 2012-03-01 00:00:00 Sending Order: ICICIBANK | Month 3 | Rebalanced: False | Pos: 252
# 2012-03-01 00:00:00 Sending Order: INFY | Month 3 | Rebalanced: False | Pos: 139
# 2012-03-01 00:00:00 Sending Order: ITC | Month 3 | Rebalanced: False | Pos: 218
# 2012-03-01 00:00:00 Sending Order: KOTAKBANK | Month 3 | Rebalanced: False | Pos: 105
# 2012-03-01 00:00:00 Sending Order: LT | Month 3 | Rebalanced: False | Pos: 57
# 2012-03-01 00:00:00 Sending Order: MARUTI | Month 3 | Rebalanced: False | Pos: 25
# 2012-03-01 00:00:00 Sending Order: NESTLEIND | Month 3 | Rebalanced: False | Pos: 5
# 2012-03-01 00:00:00 Sending Order: RELIANCE | Month 3 | Rebalanced: False | Pos: 71
# 2012-03-01 00:00:00 Sending Order: SBIN | Month 3 | Rebalanced: False | Pos: 148
# 2012-03-01 00:00:00 Sending Order: SUNPHARMA | Month 3 | Rebalanced: False | Pos: 102
# 2012-03-01 00:00:00 Sending Order: TCS | Month 3 | Rebalanced: False | Pos: 52
# 2012-03-01 00:00:00 Sending Order: WIPRO | Month 3 | Rebalanced: False | Pos: 208
# 2012-03-02 >> Order Completed >> Stock: ASIANPAINT,  Ref: 153, Size: -3, Price: 247.71819
# 2012-03-02 >> Order Completed >> Stock: AXISBANK,  Ref: 154, Size: 5, Price: 182.34203
# 2012-03-02 >> Order Completed >> Stock: BAJFINANCE,  Ref: 155, Size: -45, Price: 49.5963
# 2012-03-02 >> Order Completed >> Stock: BHARTIARTL,  Ref: 156, Size: 21, Price: 301.88519
# 2012-03-02 >> Order Completed >> Stock: HCLTECH,  Ref: 157, Size: -20, Price: 88.80768
# 2012-03-02 >> Order Completed >> Stock: HDFC,  Ref: 158, Size: 4, Price: 669.4
# 2012-03-02 >> Order Completed >> Stock: HDFCBANK,  Ref: 159, Size: -1, Price: 232.01602
# 2012-03-02 >> Order Completed >> Stock: HINDUNILVR,  Ref: 160, Size: 16, Price: 332.13049
# 2012-03-02 >> Order Completed >> Stock: ICICIBANK,  Ref: 161, Size: -17, Price: 100.26148
# 2012-03-02 >> Order Completed >> Stock: INFY,  Ref: 162, Size: 20, Price: 172.66924
# 2012-03-02 >> Order Completed >> Stock: ITC,  Ref: 163, Size: 27, Price: 114.21365
# 2012-03-02 >> Order Completed >> Stock: KOTAKBANK,  Ref: 164, Size: -11, Price: 274.77335
# 2012-03-02 >> Order Completed >> Stock: LT,  Ref: 165, Size: -3, Price: 475.96747
# 2012-03-02 >> Order Completed >> Stock: MARUTI,  Ref: 166, Size: -3, Price: 1225.09729
# 2012-03-02 >> Order Completed >> Stock: RELIANCE,  Ref: 167, Size: 2, Price: 356.8956
# 2012-03-02 >> Order Completed >> Stock: SUNPHARMA,  Ref: 169, Size: 4, Price: 262.5824
# 2012-03-02 >> Order Completed >> Stock: TCS,  Ref: 170, Size: 6, Price: 480.83868
# 2012-03-02 >> Order Completed >> Stock: WIPRO,  Ref: 171, Size: 18, Price: 123.94563
# 2012-06-01 00:00:00 Sending Order: ASIANPAINT | Month 6 | Rebalanced: False | Pos: 112
# 2012-06-01 00:00:00 Sending Order: AXISBANK | Month 6 | Rebalanced: False | Pos: 126
# 2012-06-01 00:00:00 Sending Order: BAJFINANCE | Month 6 | Rebalanced: False | Pos: 498
# 2012-06-01 00:00:00 Sending Order: BHARTIARTL | Month 6 | Rebalanced: False | Pos: 89
# 2012-06-01 00:00:00 Sending Order: HCLTECH | Month 6 | Rebalanced: False | Pos: 309
# 2012-06-01 00:00:00 Sending Order: HDFC | Month 6 | Rebalanced: False | Pos: 38
# 2012-06-01 00:00:00 Sending Order: HDFCBANK | Month 6 | Rebalanced: False | Pos: 115
# 2012-06-01 00:00:00 Sending Order: HINDUNILVR | Month 6 | Rebalanced: False | Pos: 85
# 2012-06-01 00:00:00 Sending Order: ICICIBANK | Month 6 | Rebalanced: False | Pos: 235
# 2012-06-01 00:00:00 Sending Order: INFY | Month 6 | Rebalanced: False | Pos: 159
# 2012-06-01 00:00:00 Sending Order: ITC | Month 6 | Rebalanced: False | Pos: 245
# 2012-06-01 00:00:00 Sending Order: KOTAKBANK | Month 6 | Rebalanced: False | Pos: 94
# 2012-06-01 00:00:00 Sending Order: LT | Month 6 | Rebalanced: False | Pos: 54
# 2012-06-01 00:00:00 Sending Order: MARUTI | Month 6 | Rebalanced: False | Pos: 22
# 2012-06-01 00:00:00 Sending Order: NESTLEIND | Month 6 | Rebalanced: False | Pos: 5
# 2012-06-01 00:00:00 Sending Order: RELIANCE | Month 6 | Rebalanced: False | Pos: 73
# 2012-06-01 00:00:00 Sending Order: SBIN | Month 6 | Rebalanced: False | Pos: 148
# 2012-06-01 00:00:00 Sending Order: SUNPHARMA | Month 6 | Rebalanced: False | Pos: 106
# 2012-06-01 00:00:00 Sending Order: TCS | Month 6 | Rebalanced: False | Pos: 58
# 2012-06-01 00:00:00 Sending Order: WIPRO | Month 6 | Rebalanced: False | Pos: 226
# 2012-06-04 >> Order Completed >> Stock: ASIANPAINT,  Ref: 172, Size: -21, Price: 297.27914
# 2012-06-04 >> Order Completed >> Stock: AXISBANK,  Ref: 173, Size: 22, Price: 152.5527
# 2012-06-04 >> Order Completed >> Stock: BAJFINANCE,  Ref: 174, Size: -51, Price: 54.20798
# 2012-06-04 >> Order Completed >> Stock: BHARTIARTL,  Ref: 175, Size: 11, Price: 262.26459
# 2012-06-04 >> Order Completed >> Stock: HCLTECH,  Ref: 176, Size: -14, Price: 91.19094
# 2012-06-04 >> Order Completed >> Stock: HDFCBANK,  Ref: 177, Size: 2, Price: 221.36316
# 2012-06-04 >> Order Completed >> Stock: HINDUNILVR,  Ref: 178, Size: -8, Price: 366.31723
# 2012-06-04 >> Order Completed >> Stock: ICICIBANK,  Ref: 179, Size: -4, Price: 99.79004
# 2012-06-04 >> Order Completed >> Stock: INFY,  Ref: 180, Size: 13, Price: 156.11551
# 2012-06-04 >> Order Completed >> Stock: ITC,  Ref: 181, Size: -32, Price: 129.12189
# 2012-06-04 >> Order Completed >> Stock: LT,  Ref: 182, Size: 4, Price: 422.70526
# 2012-06-04 >> Order Completed >> Stock: MARUTI,  Ref: 183, Size: 3, Price: 1001.32751
# 2012-06-04 >> Order Completed >> Stock: RELIANCE,  Ref: 184, Size: 9, Price: 309.0137
# 2012-06-04 >> Order Completed >> Stock: SUNPHARMA,  Ref: 186, Size: -4, Price: 271.50446
# 2012-06-04 >> Order Completed >> Stock: TCS,  Ref: 187, Size: -1, Price: 482.81024
# 2012-06-04 >> Order Completed >> Stock: WIPRO,  Ref: 188, Size: 8, Price: 117.13297
# 2012-09-03 00:00:00 Sending Order: ASIANPAINT | Month 9 | Rebalanced: False | Pos: 91
# 2012-09-03 00:00:00 Sending Order: AXISBANK | Month 9 | Rebalanced: False | Pos: 148
# 2012-09-03 00:00:00 Sending Order: BAJFINANCE | Month 9 | Rebalanced: False | Pos: 447
# 2012-09-03 00:00:00 Sending Order: BHARTIARTL | Month 9 | Rebalanced: False | Pos: 100
# 2012-09-03 00:00:00 Sending Order: HCLTECH | Month 9 | Rebalanced: False | Pos: 295
# 2012-09-03 00:00:00 Sending Order: HDFC | Month 9 | Rebalanced: False | Pos: 38
# 2012-09-03 00:00:00 Sending Order: HDFCBANK | Month 9 | Rebalanced: False | Pos: 117
# 2012-09-03 00:00:00 Sending Order: HINDUNILVR | Month 9 | Rebalanced: False | Pos: 77
# 2012-09-03 00:00:00 Sending Order: ICICIBANK | Month 9 | Rebalanced: False | Pos: 231
# 2012-09-03 00:00:00 Sending Order: INFY | Month 9 | Rebalanced: False | Pos: 172
# 2012-09-03 00:00:00 Sending Order: ITC | Month 9 | Rebalanced: False | Pos: 213
# 2012-09-03 00:00:00 Sending Order: KOTAKBANK | Month 9 | Rebalanced: False | Pos: 94
# 2012-09-03 00:00:00 Sending Order: LT | Month 9 | Rebalanced: False | Pos: 58
# 2012-09-03 00:00:00 Sending Order: MARUTI | Month 9 | Rebalanced: False | Pos: 25
# 2012-09-03 00:00:00 Sending Order: NESTLEIND | Month 9 | Rebalanced: False | Pos: 5
# 2012-09-03 00:00:00 Sending Order: RELIANCE | Month 9 | Rebalanced: False | Pos: 82
# 2012-09-03 00:00:00 Sending Order: SBIN | Month 9 | Rebalanced: False | Pos: 148
# 2012-09-03 00:00:00 Sending Order: SUNPHARMA | Month 9 | Rebalanced: False | Pos: 102
# 2012-09-03 00:00:00 Sending Order: TCS | Month 9 | Rebalanced: False | Pos: 57
# 2012-09-03 00:00:00 Sending Order: WIPRO | Month 9 | Rebalanced: False | Pos: 234
# 2012-09-04 >> Order Completed >> Stock: ASIANPAINT,  Ref: 189, Size: 5, Price: 312.03659
# 2012-09-04 >> Order Completed >> Stock: AXISBANK,  Ref: 190, Size: 2, Price: 167.43929
# 2012-09-04 >> Order Completed >> Stock: BAJFINANCE,  Ref: 191, Size: -101, Price: 77.6203
# 2012-09-04 >> Order Completed >> Stock: BHARTIARTL,  Ref: 192, Size: 35, Price: 216.09238
# 2012-09-04 >> Order Completed >> Stock: HCLTECH,  Ref: 193, Size: -8, Price: 104.00522
# 2012-09-04 >> Order Completed >> Stock: HDFCBANK,  Ref: 194, Size: -10, Price: 270.76657
# 2012-09-04 >> Order Completed >> Stock: HINDUNILVR,  Ref: 195, Size: -8, Price: 453.91122
# 2012-09-04 >> Order Completed >> Stock: ICICIBANK,  Ref: 196, Size: -9, Price: 115.24928
# 2012-09-04 >> Order Completed >> Stock: INFY,  Ref: 197, Size: 21, Price: 154.54103
# 2012-09-04 >> Order Completed >> Stock: ITC,  Ref: 198, Size: -12, Price: 152.04782
# 2012-09-04 >> Order Completed >> Stock: KOTAKBANK,  Ref: 199, Size: 3, Price: 285.22388
# 2012-09-04 >> Order Completed >> Stock: LT,  Ref: 200, Size: -4, Price: 516.9281
# 2012-09-04 >> Order Completed >> Stock: MARUTI,  Ref: 201, Size: 1, Price: 1089.88013
# 2012-09-04 >> Order Completed >> Stock: SUNPHARMA,  Ref: 203, Size: -7, Price: 322.15793
# 2012-09-04 >> Order Completed >> Stock: WIPRO,  Ref: 204, Size: 44, Price: 109.16848
# 2013-01-01 00:00:00 Sending Order: ASIANPAINT | Month 1 | Rebalanced: False | Pos: 96
# 2013-01-01 00:00:00 Sending Order: AXISBANK | Month 1 | Rebalanced: False | Pos: 150
# 2013-01-01 00:00:00 Sending Order: BAJFINANCE | Month 1 | Rebalanced: False | Pos: 346
# 2013-01-01 00:00:00 Sending Order: BHARTIARTL | Month 1 | Rebalanced: False | Pos: 135
# 2013-01-01 00:00:00 Sending Order: HCLTECH | Month 1 | Rebalanced: False | Pos: 287
# 2013-01-01 00:00:00 Sending Order: HDFC | Month 1 | Rebalanced: False | Pos: 38
# 2013-01-01 00:00:00 Sending Order: HDFCBANK | Month 1 | Rebalanced: False | Pos: 107
# 2013-01-01 00:00:00 Sending Order: HINDUNILVR | Month 1 | Rebalanced: False | Pos: 69
# 2013-01-01 00:00:00 Sending Order: ICICIBANK | Month 1 | Rebalanced: False | Pos: 222
# 2013-01-01 00:00:00 Sending Order: INFY | Month 1 | Rebalanced: False | Pos: 193
# 2013-01-01 00:00:00 Sending Order: ITC | Month 1 | Rebalanced: False | Pos: 201
# 2013-01-01 00:00:00 Sending Order: KOTAKBANK | Month 1 | Rebalanced: False | Pos: 97
# 2013-01-01 00:00:00 Sending Order: LT | Month 1 | Rebalanced: False | Pos: 54
# 2013-01-01 00:00:00 Sending Order: MARUTI | Month 1 | Rebalanced: False | Pos: 26
# 2013-01-01 00:00:00 Sending Order: NESTLEIND | Month 1 | Rebalanced: False | Pos: 5
# 2013-01-01 00:00:00 Sending Order: RELIANCE | Month 1 | Rebalanced: False | Pos: 82
# 2013-01-01 00:00:00 Sending Order: SBIN | Month 1 | Rebalanced: False | Pos: 148
# 2013-01-01 00:00:00 Sending Order: SUNPHARMA | Month 1 | Rebalanced: False | Pos: 95
# 2013-01-01 00:00:00 Sending Order: TCS | Month 1 | Rebalanced: False | Pos: 57
# 2013-01-01 00:00:00 Sending Order: WIPRO | Month 1 | Rebalanced: False | Pos: 278
# 2013-01-02 >> Order Completed >> Stock: ASIANPAINT,  Ref: 205, Size: -6, Price: 387.46835
# 2013-01-02 >> Order Completed >> Stock: AXISBANK,  Ref: 206, Size: -24, Price: 233.39761
# 2013-01-02 >> Order Completed >> Stock: BAJFINANCE,  Ref: 207, Size: -38, Price: 101.16312
# 2013-01-02 >> Order Completed >> Stock: BHARTIARTL,  Ref: 208, Size: -14, Price: 281.96631
# 2013-01-02 >> Order Completed >> Stock: HCLTECH,  Ref: 209, Size: 1, Price: 119.6599
# 2013-01-02 >> Order Completed >> Stock: HINDUNILVR,  Ref: 210, Size: 7, Price: 471.45139
# 2013-01-02 >> Order Completed >> Stock: ICICIBANK,  Ref: 211, Size: -21, Price: 147.88515
# 2013-01-02 >> Order Completed >> Stock: INFY,  Ref: 212, Size: 25, Price: 158.91072
# 2013-01-02 >> Order Completed >> Stock: ITC,  Ref: 213, Size: 15, Price: 163.21277
# 2013-01-02 >> Order Completed >> Stock: KOTAKBANK,  Ref: 214, Size: 3, Price: 322.54239
# 2013-01-02 >> Order Completed >> Stock: LT,  Ref: 215, Size: -2, Price: 621.22418
# 2013-01-02 >> Order Completed >> Stock: MARUTI,  Ref: 216, Size: -2, Price: 1419.79749
# 2013-01-02 >> Order Completed >> Stock: RELIANCE,  Ref: 217, Size: 4, Price: 379.11395
# 2013-01-02 >> Order Completed >> Stock: SBIN,  Ref: 218, Size: 38, Price: 162.69435
# 2013-01-02 >> Order Completed >> Stock: SUNPHARMA,  Ref: 219, Size: 4, Price: 357.28232
# 2013-01-02 >> Order Completed >> Stock: WIPRO,  Ref: 221, Size: 19, Price: 118.97062
# 2013-03-01 00:00:00 Sending Order: ASIANPAINT | Month 3 | Rebalanced: False | Pos: 90
# 2013-03-01 00:00:00 Sending Order: AXISBANK | Month 3 | Rebalanced: False | Pos: 126
# 2013-03-01 00:00:00 Sending Order: BAJFINANCE | Month 3 | Rebalanced: False | Pos: 308
# 2013-03-01 00:00:00 Sending Order: BHARTIARTL | Month 3 | Rebalanced: False | Pos: 121
# 2013-03-01 00:00:00 Sending Order: HCLTECH | Month 3 | Rebalanced: False | Pos: 288
# 2013-03-01 00:00:00 Sending Order: HDFC | Month 3 | Rebalanced: False | Pos: 38
# 2013-03-01 00:00:00 Sending Order: HDFCBANK | Month 3 | Rebalanced: False | Pos: 107
# 2013-03-01 00:00:00 Sending Order: HINDUNILVR | Month 3 | Rebalanced: False | Pos: 76
# 2013-03-01 00:00:00 Sending Order: ICICIBANK | Month 3 | Rebalanced: False | Pos: 201
# 2013-03-01 00:00:00 Sending Order: INFY | Month 3 | Rebalanced: False | Pos: 218
# 2013-03-01 00:00:00 Sending Order: ITC | Month 3 | Rebalanced: False | Pos: 216
# 2013-03-01 00:00:00 Sending Order: KOTAKBANK | Month 3 | Rebalanced: False | Pos: 100
# 2013-03-01 00:00:00 Sending Order: LT | Month 3 | Rebalanced: False | Pos: 52
# 2013-03-01 00:00:00 Sending Order: MARUTI | Month 3 | Rebalanced: False | Pos: 24
# 2013-03-01 00:00:00 Sending Order: NESTLEIND | Month 3 | Rebalanced: False | Pos: 5
# 2013-03-01 00:00:00 Sending Order: RELIANCE | Month 3 | Rebalanced: False | Pos: 86
# 2013-03-01 00:00:00 Sending Order: SBIN | Month 3 | Rebalanced: False | Pos: 186
# 2013-03-01 00:00:00 Sending Order: SUNPHARMA | Month 3 | Rebalanced: False | Pos: 99
# 2013-03-01 00:00:00 Sending Order: TCS | Month 3 | Rebalanced: False | Pos: 57
# 2013-03-01 00:00:00 Sending Order: WIPRO | Month 3 | Rebalanced: False | Pos: 297
# 2013-03-04 >> Order Completed >> Stock: AXISBANK,  Ref: 222, Size: -2, Price: 233.56888
# 2013-03-04 >> Order Completed >> Stock: BAJFINANCE,  Ref: 223, Size: 7, Price: 97.80335
# 2013-03-04 >> Order Completed >> Stock: BHARTIARTL,  Ref: 224, Size: 2, Price: 272.33691
# 2013-03-04 >> Order Completed >> Stock: HCLTECH,  Ref: 225, Size: -44, Price: 140.54417
# 2013-03-04 >> Order Completed >> Stock: HDFC,  Ref: 226, Size: 2, Price: 777.5
# 2013-03-04 >> Order Completed >> Stock: HDFCBANK,  Ref: 227, Size: 8, Price: 285.4639
# 2013-03-04 >> Order Completed >> Stock: HINDUNILVR,  Ref: 228, Size: 12, Price: 402.32407
# 2013-03-04 >> Order Completed >> Stock: INFY,  Ref: 230, Size: -46, Price: 200.54771
# 2013-03-04 >> Order Completed >> Stock: ITC,  Ref: 231, Size: -4, Price: 165.48581
# 2013-03-04 >> Order Completed >> Stock: KOTAKBANK,  Ref: 232, Size: -1, Price: 324.974
# 2013-03-04 >> Order Completed >> Stock: LT,  Ref: 233, Size: 7, Price: 535.41315
# 2013-03-04 >> Order Completed >> Stock: RELIANCE,  Ref: 234, Size: 3, Price: 365.4502
# 2013-03-04 >> Order Completed >> Stock: SBIN,  Ref: 235, Size: 29, Price: 139.97769
# 2013-03-04 >> Order Completed >> Stock: SUNPHARMA,  Ref: 236, Size: -8, Price: 386.19821
# 2013-03-04 >> Order Completed >> Stock: WIPRO,  Ref: 237, Size: -23, Price: 128.11803
# 2013-06-03 00:00:00 Sending Order: ASIANPAINT | Month 6 | Rebalanced: False | Pos: 90
# 2013-06-03 00:00:00 Sending Order: AXISBANK | Month 6 | Rebalanced: False | Pos: 124
# 2013-06-03 00:00:00 Sending Order: BAJFINANCE | Month 6 | Rebalanced: False | Pos: 315
# 2013-06-03 00:00:00 Sending Order: BHARTIARTL | Month 6 | Rebalanced: False | Pos: 123
# 2013-06-03 00:00:00 Sending Order: HCLTECH | Month 6 | Rebalanced: False | Pos: 244
# 2013-06-03 00:00:00 Sending Order: HDFC | Month 6 | Rebalanced: False | Pos: 40
# 2013-06-03 00:00:00 Sending Order: HDFCBANK | Month 6 | Rebalanced: False | Pos: 115
# 2013-06-03 00:00:00 Sending Order: HINDUNILVR | Month 6 | Rebalanced: False | Pos: 88
# 2013-06-03 00:00:00 Sending Order: ICICIBANK | Month 6 | Rebalanced: False | Pos: 201
# 2013-06-03 00:00:00 Sending Order: INFY | Month 6 | Rebalanced: False | Pos: 172
# 2013-06-03 00:00:00 Sending Order: ITC | Month 6 | Rebalanced: False | Pos: 212
# 2013-06-03 00:00:00 Sending Order: KOTAKBANK | Month 6 | Rebalanced: False | Pos: 99
# 2013-06-03 00:00:00 Sending Order: LT | Month 6 | Rebalanced: False | Pos: 59
# 2013-06-03 00:00:00 Sending Order: MARUTI | Month 6 | Rebalanced: False | Pos: 24
# 2013-06-03 00:00:00 Sending Order: NESTLEIND | Month 6 | Rebalanced: False | Pos: 5
# 2013-06-03 00:00:00 Sending Order: RELIANCE | Month 6 | Rebalanced: False | Pos: 89
# 2013-06-03 00:00:00 Sending Order: SBIN | Month 6 | Rebalanced: False | Pos: 215
# 2013-06-03 00:00:00 Sending Order: SUNPHARMA | Month 6 | Rebalanced: False | Pos: 91
# 2013-06-03 00:00:00 Sending Order: TCS | Month 6 | Rebalanced: False | Pos: 57
# 2013-06-03 00:00:00 Sending Order: WIPRO | Month 6 | Rebalanced: False | Pos: 274
# 2013-06-04 >> Order Completed >> Stock: ASIANPAINT,  Ref: 238, Size: 1, Price: 411.23038
# 2013-06-04 >> Order Completed >> Stock: AXISBANK,  Ref: 239, Size: 5, Price: 245.0701
# 2013-06-04 >> Order Completed >> Stock: BAJFINANCE,  Ref: 240, Size: -15, Price: 112.72212
# 2013-06-04 >> Order Completed >> Stock: BHARTIARTL,  Ref: 241, Size: 15, Price: 266.52655
# 2013-06-04 >> Order Completed >> Stock: HCLTECH,  Ref: 242, Size: 13, Price: 145.96259
# 2013-06-04 >> Order Completed >> Stock: HINDUNILVR,  Ref: 243, Size: -13, Price: 526.09564
# 2013-06-04 >> Order Completed >> Stock: INFY,  Ref: 244, Size: 26, Price: 190.53279
# 2013-06-04 >> Order Completed >> Stock: ITC,  Ref: 245, Size: -15, Price: 195.28069
# 2013-06-04 >> Order Completed >> Stock: KOTAKBANK,  Ref: 246, Size: -6, Price: 382.31656
# 2013-06-04 >> Order Completed >> Stock: LT,  Ref: 247, Size: 6, Price: 530.38605
# 2013-06-04 >> Order Completed >> Stock: RELIANCE,  Ref: 248, Size: 9, Price: 363.29715
# 2013-06-04 >> Order Completed >> Stock: SBIN,  Ref: 249, Size: -22, Price: 171.75049
# 2013-06-04 >> Order Completed >> Stock: SUNPHARMA,  Ref: 250, Size: -12, Price: 491.66785
# 2013-06-04 >> Order Completed >> Stock: TCS,  Ref: 251, Size: 7, Price: 595.14325
# 2013-09-02 00:00:00 Sending Order: ASIANPAINT | Month 9 | Rebalanced: False | Pos: 91
# 2013-09-02 00:00:00 Sending Order: AXISBANK | Month 9 | Rebalanced: False | Pos: 129
# 2013-09-02 00:00:00 Sending Order: BAJFINANCE | Month 9 | Rebalanced: False | Pos: 300
# 2013-09-02 00:00:00 Sending Order: BHARTIARTL | Month 9 | Rebalanced: False | Pos: 138
# 2013-09-02 00:00:00 Sending Order: HCLTECH | Month 9 | Rebalanced: False | Pos: 257
# 2013-09-02 00:00:00 Sending Order: HDFC | Month 9 | Rebalanced: False | Pos: 40
# 2013-09-02 00:00:00 Sending Order: HDFCBANK | Month 9 | Rebalanced: False | Pos: 115
# 2013-09-02 00:00:00 Sending Order: HINDUNILVR | Month 9 | Rebalanced: False | Pos: 75
# 2013-09-02 00:00:00 Sending Order: ICICIBANK | Month 9 | Rebalanced: False | Pos: 201
# 2013-09-02 00:00:00 Sending Order: INFY | Month 9 | Rebalanced: False | Pos: 198
# 2013-09-02 00:00:00 Sending Order: ITC | Month 9 | Rebalanced: False | Pos: 197
# 2013-09-02 00:00:00 Sending Order: KOTAKBANK | Month 9 | Rebalanced: False | Pos: 93
# 2013-09-02 00:00:00 Sending Order: LT | Month 9 | Rebalanced: False | Pos: 65
# 2013-09-02 00:00:00 Sending Order: MARUTI | Month 9 | Rebalanced: False | Pos: 24
# 2013-09-02 00:00:00 Sending Order: NESTLEIND | Month 9 | Rebalanced: False | Pos: 5
# 2013-09-02 00:00:00 Sending Order: RELIANCE | Month 9 | Rebalanced: False | Pos: 98
# 2013-09-02 00:00:00 Sending Order: SBIN | Month 9 | Rebalanced: False | Pos: 193
# 2013-09-02 00:00:00 Sending Order: SUNPHARMA | Month 9 | Rebalanced: False | Pos: 79
# 2013-09-02 00:00:00 Sending Order: TCS | Month 9 | Rebalanced: False | Pos: 64
# 2013-09-02 00:00:00 Sending Order: WIPRO | Month 9 | Rebalanced: False | Pos: 274
# 2013-09-03 >> Order Completed >> Stock: ASIANPAINT,  Ref: 253, Size: 1, Price: 401.36609
# 2013-09-03 >> Order Completed >> Stock: BAJFINANCE,  Ref: 255, Size: 86, Price: 86.30278
# 2013-09-03 >> Order Completed >> Stock: HCLTECH,  Ref: 256, Size: -75, Price: 204.2169
# 2013-09-03 >> Order Completed >> Stock: HDFC,  Ref: 257, Size: 6, Price: 738.4
# 2013-09-03 >> Order Completed >> Stock: HDFCBANK,  Ref: 258, Size: 15, Price: 274.88504
# 2013-09-03 >> Order Completed >> Stock: HINDUNILVR,  Ref: 259, Size: -8, Price: 575.51917
# 2013-09-03 >> Order Completed >> Stock: ICICIBANK,  Ref: 260, Size: 72, Price: 116.02752
# 2013-09-03 >> Order Completed >> Stock: INFY,  Ref: 261, Size: -38, Price: 233.86633
# 2013-09-03 >> Order Completed >> Stock: ITC,  Ref: 262, Size: 6, Price: 186.18665
# 2013-09-03 >> Order Completed >> Stock: KOTAKBANK,  Ref: 263, Size: 18, Price: 311.77786
# 2013-09-03 >> Order Completed >> Stock: LT,  Ref: 264, Size: 15, Price: 427.19086
# 2013-09-03 >> Order Completed >> Stock: MARUTI,  Ref: 265, Size: 4, Price: 1225.89624
# 2013-09-03 >> Order Completed >> Stock: RELIANCE,  Ref: 266, Size: -11, Price: 408.8764
# 2013-09-03 >> Order Completed >> Stock: SUNPHARMA,  Ref: 268, Size: -4, Price: 510.63098
# 2013-09-03 >> Order Completed >> Stock: TCS,  Ref: 269, Size: -19, Price: 851.94275
# 2013-09-03 >> Order Completed >> Stock: WIPRO,  Ref: 270, Size: -26, Price: 153.04408
# 2014-01-01 00:00:00 Sending Order: ASIANPAINT | Month 1 | Rebalanced: False | Pos: 92
# 2014-01-01 00:00:00 Sending Order: AXISBANK | Month 1 | Rebalanced: False | Pos: 129
# ...
# 2019-01-02 >> Order Completed >> Stock: NESTLEIND,  Ref: 640, Size: -1, Price: 10613.58496
# 2019-01-02 >> Order Completed >> Stock: RELIANCE,  Ref: 641, Size: 4, Price: 1114.88428
# 2019-01-02 >> Order Completed >> Stock: SBIN,  Ref: 642, Size: -7, Price: 299.60001
# 2019-01-02 >> Order Completed >> Stock: TCS,  Ref: 644, Size: 1, Price: 1819.51367
# 2019-01-02 >> Order Completed >> Stock: WIPRO,  Ref: 645, Size: -52, Price: 243.31589
# 2019-03-01 00:00:00 Sending Order: ASIANPAINT | Month 3 | Rebalanced: False | Pos: 86
# 2019-03-01 00:00:00 Sending Order: AXISBANK | Month 3 | Rebalanced: False | Pos: 158
# 2019-03-01 00:00:00 Sending Order: BAJFINANCE | Month 3 | Rebalanced: False | Pos: 40
# 2019-03-01 00:00:00 Sending Order: BHARTIARTL | Month 3 | Rebalanced: False | Pos: 390
# 2019-03-01 00:00:00 Sending Order: HCLTECH | Month 3 | Rebalanced: False | Pos: 245
# 2019-03-01 00:00:00 Sending Order: HDFC | Month 3 | Rebalanced: False | Pos: 54
# 2019-03-01 00:00:00 Sending Order: HDFCBANK | Month 3 | Rebalanced: False | Pos: 105
# 2019-03-01 00:00:00 Sending Order: HINDUNILVR | Month 3 | Rebalanced: False | Pos: 68
# 2019-03-01 00:00:00 Sending Order: ICICIBANK | Month 3 | Rebalanced: False | Pos: 277
# 2019-03-01 00:00:00 Sending Order: INFY | Month 3 | Rebalanced: False | Pos: 186
# 2019-03-01 00:00:00 Sending Order: ITC | Month 3 | Rebalanced: False | Pos: 430
# 2019-03-01 00:00:00 Sending Order: KOTAKBANK | Month 3 | Rebalanced: False | Pos: 87
# 2019-03-01 00:00:00 Sending Order: LT | Month 3 | Rebalanced: False | Pos: 76
# 2019-03-01 00:00:00 Sending Order: MARUTI | Month 3 | Rebalanced: False | Pos: 15
# 2019-03-01 00:00:00 Sending Order: NESTLEIND | Month 3 | Rebalanced: False | Pos: 8
# 2019-03-01 00:00:00 Sending Order: RELIANCE | Month 3 | Rebalanced: False | Pos: 99
# 2019-03-01 00:00:00 Sending Order: SBIN | Month 3 | Rebalanced: False | Pos: 343
# 2019-03-01 00:00:00 Sending Order: SUNPHARMA | Month 3 | Rebalanced: False | Pos: 193
# 2019-03-01 00:00:00 Sending Order: TCS | Month 3 | Rebalanced: False | Pos: 65
# 2019-03-01 00:00:00 Sending Order: WIPRO | Month 3 | Rebalanced: False | Pos: 490
# 2019-03-05 >> Order Completed >> Stock: AXISBANK,  Ref: 646, Size: -16, Price: 701.52881
# 2019-03-05 >> Order Completed >> Stock: BHARTIARTL,  Ref: 647, Size: 18, Price: 282.478
# 2019-03-05 >> Order Completed >> Stock: HCLTECH,  Ref: 648, Size: -19, Price: 521.67206
# 2019-03-05 >> Order Completed >> Stock: HDFC,  Ref: 649, Size: 4, Price: 1859.45
# 2019-03-05 >> Order Completed >> Stock: HDFCBANK,  Ref: 650, Size: 4, Price: 1032.94666
# 2019-03-05 >> Order Completed >> Stock: HINDUNILVR,  Ref: 651, Size: 3, Price: 1713.29785
# 2019-03-05 >> Order Completed >> Stock: ICICIBANK,  Ref: 652, Size: 8, Price: 352.52783
# 2019-03-05 >> Order Completed >> Stock: INFY,  Ref: 653, Size: -18, Price: 705.34314
# 2019-03-05 >> Order Completed >> Stock: ITC,  Ref: 654, Size: 10, Price: 272.9707
# 2019-03-05 >> Order Completed >> Stock: KOTAKBANK,  Ref: 655, Size: 2, Price: 1225.28943
# 2019-03-05 >> Order Completed >> Stock: LT,  Ref: 656, Size: 9, Price: 1273.99731
# 2019-03-05 >> Order Completed >> Stock: MARUTI,  Ref: 657, Size: 1, Price: 6839.74707
# 2019-03-05 >> Order Completed >> Stock: RELIANCE,  Ref: 658, Size: -7, Price: 1219.36121
# 2019-03-05 >> Order Completed >> Stock: SBIN,  Ref: 659, Size: 35, Price: 272.95001
# 2019-03-05 >> Order Completed >> Stock: TCS,  Ref: 661, Size: -2, Price: 1912.15015
# 2019-03-05 >> Order Completed >> Stock: WIPRO,  Ref: 662, Size: -61, Price: 280.642
# 2019-06-03 00:00:00 Sending Order: ASIANPAINT | Month 6 | Rebalanced: False | Pos: 86
# 2019-06-03 00:00:00 Sending Order: AXISBANK | Month 6 | Rebalanced: False | Pos: 142
# 2019-06-03 00:00:00 Sending Order: BAJFINANCE | Month 6 | Rebalanced: False | Pos: 40
# 2019-06-03 00:00:00 Sending Order: BHARTIARTL | Month 6 | Rebalanced: False | Pos: 408
# 2019-06-03 00:00:00 Sending Order: HCLTECH | Month 6 | Rebalanced: False | Pos: 226
# 2019-06-03 00:00:00 Sending Order: HDFC | Month 6 | Rebalanced: False | Pos: 58
# 2019-06-03 00:00:00 Sending Order: HDFCBANK | Month 6 | Rebalanced: False | Pos: 109
# 2019-06-03 00:00:00 Sending Order: HINDUNILVR | Month 6 | Rebalanced: False | Pos: 71
# 2019-06-03 00:00:00 Sending Order: ICICIBANK | Month 6 | Rebalanced: False | Pos: 285
# 2019-06-03 00:00:00 Sending Order: INFY | Month 6 | Rebalanced: False | Pos: 168
# 2019-06-03 00:00:00 Sending Order: ITC | Month 6 | Rebalanced: False | Pos: 440
# 2019-06-03 00:00:00 Sending Order: KOTAKBANK | Month 6 | Rebalanced: False | Pos: 89
# 2019-06-03 00:00:00 Sending Order: LT | Month 6 | Rebalanced: False | Pos: 85
# 2019-06-03 00:00:00 Sending Order: MARUTI | Month 6 | Rebalanced: False | Pos: 16
# 2019-06-03 00:00:00 Sending Order: NESTLEIND | Month 6 | Rebalanced: False | Pos: 8
# 2019-06-03 00:00:00 Sending Order: RELIANCE | Month 6 | Rebalanced: False | Pos: 92
# 2019-06-03 00:00:00 Sending Order: SBIN | Month 6 | Rebalanced: False | Pos: 378
# 2019-06-03 00:00:00 Sending Order: SUNPHARMA | Month 6 | Rebalanced: False | Pos: 193
# 2019-06-03 00:00:00 Sending Order: TCS | Month 6 | Rebalanced: False | Pos: 63
# 2019-06-03 00:00:00 Sending Order: WIPRO | Month 6 | Rebalanced: False | Pos: 429
# 2019-06-04 >> Order Completed >> Stock: ASIANPAINT,  Ref: 663, Size: 6, Price: 1442.94141
# 2019-06-04 >> Order Completed >> Stock: AXISBANK,  Ref: 664, Size: -4, Price: 811.64203
# 2019-06-04 >> Order Completed >> Stock: BAJFINANCE,  Ref: 665, Size: -5, Price: 3496.86914
# 2019-06-04 >> Order Completed >> Stock: BHARTIARTL,  Ref: 666, Size: -39, Price: 352.75
# 2019-06-04 >> Order Completed >> Stock: HCLTECH,  Ref: 667, Size: 12, Price: 553.73425
# 2019-06-04 >> Order Completed >> Stock: HDFC,  Ref: 668, Size: -2, Price: 2230.45
# 2019-06-04 >> Order Completed >> Stock: HDFCBANK,  Ref: 669, Size: -4, Price: 1218.25
# 2019-06-04 >> Order Completed >> Stock: HINDUNILVR,  Ref: 670, Size: 4, Price: 1817.05469
# 2019-06-04 >> Order Completed >> Stock: ICICIBANK,  Ref: 671, Size: -15, Price: 420.84409
# 2019-06-04 >> Order Completed >> Stock: INFY,  Ref: 672, Size: 19, Price: 707.95764
# 2019-06-04 >> Order Completed >> Stock: ITC,  Ref: 673, Size: 45, Price: 278.54999
# 2019-06-04 >> Order Completed >> Stock: KOTAKBANK,  Ref: 674, Size: -7, Price: 1530.42505
# 2019-06-04 >> Order Completed >> Stock: LT,  Ref: 675, Size: -4, Price: 1518.22351
# 2019-06-04 >> Order Completed >> Stock: MARUTI,  Ref: 676, Size: 2, Price: 6926.28955
# 2019-06-04 >> Order Completed >> Stock: SBIN,  Ref: 677, Size: -50, Price: 355.45001
# 2019-06-04 >> Order Completed >> Stock: SUNPHARMA,  Ref: 678, Size: 136, Price: 411.1412
# 2019-09-03 00:00:00 Sending Order: ASIANPAINT | Month 9 | Rebalanced: False | Pos: 92
# 2019-09-03 00:00:00 Sending Order: AXISBANK | Month 9 | Rebalanced: False | Pos: 138
# 2019-09-03 00:00:00 Sending Order: BAJFINANCE | Month 9 | Rebalanced: False | Pos: 35
# 2019-09-03 00:00:00 Sending Order: BHARTIARTL | Month 9 | Rebalanced: False | Pos: 369
# 2019-09-03 00:00:00 Sending Order: HCLTECH | Month 9 | Rebalanced: False | Pos: 238
# 2019-09-03 00:00:00 Sending Order: HDFC | Month 9 | Rebalanced: False | Pos: 56
# 2019-09-03 00:00:00 Sending Order: HDFCBANK | Month 9 | Rebalanced: False | Pos: 105
# 2019-09-03 00:00:00 Sending Order: HINDUNILVR | Month 9 | Rebalanced: False | Pos: 75
# 2019-09-03 00:00:00 Sending Order: ICICIBANK | Month 9 | Rebalanced: False | Pos: 270
# 2019-09-03 00:00:00 Sending Order: INFY | Month 9 | Rebalanced: False | Pos: 187
# 2019-09-03 00:00:00 Sending Order: ITC | Month 9 | Rebalanced: False | Pos: 485
# 2019-09-03 00:00:00 Sending Order: KOTAKBANK | Month 9 | Rebalanced: False | Pos: 82
# 2019-09-03 00:00:00 Sending Order: LT | Month 9 | Rebalanced: False | Pos: 81
# 2019-09-03 00:00:00 Sending Order: MARUTI | Month 9 | Rebalanced: False | Pos: 18
# 2019-09-03 00:00:00 Sending Order: NESTLEIND | Month 9 | Rebalanced: False | Pos: 8
# 2019-09-03 00:00:00 Sending Order: RELIANCE | Month 9 | Rebalanced: False | Pos: 92
# 2019-09-03 00:00:00 Sending Order: SBIN | Month 9 | Rebalanced: False | Pos: 328
# 2019-09-03 00:00:00 Sending Order: SUNPHARMA | Month 9 | Rebalanced: False | Pos: 329
# 2019-09-03 00:00:00 Sending Order: TCS | Month 9 | Rebalanced: False | Pos: 63
# 2019-09-03 00:00:00 Sending Order: WIPRO | Month 9 | Rebalanced: False | Pos: 429
# 2019-09-04 >> Order Completed >> Stock: ASIANPAINT,  Ref: 680, Size: -11, Price: 1567.54077
# 2019-09-04 >> Order Completed >> Stock: AXISBANK,  Ref: 681, Size: 25, Price: 645.70001
# 2019-09-04 >> Order Completed >> Stock: BHARTIARTL,  Ref: 682, Size: -5, Price: 336.85001
# 2019-09-04 >> Order Completed >> Stock: HCLTECH,  Ref: 683, Size: -11, Price: 551.36127
# 2019-09-04 >> Order Completed >> Stock: HDFCBANK,  Ref: 684, Size: 3, Price: 1105.46997
# 2019-09-04 >> Order Completed >> Stock: HINDUNILVR,  Ref: 685, Size: -4, Price: 1832.32617
# 2019-09-04 >> Order Completed >> Stock: ICICIBANK,  Ref: 686, Size: 2, Price: 392.14999
# 2019-09-04 >> Order Completed >> Stock: INFY,  Ref: 687, Size: -27, Price: 785.0636
# 2019-09-04 >> Order Completed >> Stock: ITC,  Ref: 688, Size: 43, Price: 241.55
# 2019-09-04 >> Order Completed >> Stock: LT,  Ref: 689, Size: 9, Price: 1276.52283
# 2019-09-04 >> Order Completed >> Stock: MARUTI,  Ref: 690, Size: 1, Price: 6049.7002
# 2019-09-04 >> Order Completed >> Stock: RELIANCE,  Ref: 691, Size: 6, Price: 1206.40002
# 2019-09-04 >> Order Completed >> Stock: SUNPHARMA,  Ref: 693, Size: -36, Price: 436.20093
# 2019-09-04 >> Order Completed >> Stock: TCS,  Ref: 694, Size: -4, Price: 2180.20264
# 2019-09-04 >> Order Completed >> Stock: WIPRO,  Ref: 695, Size: 75, Price: 252.63008
# 2020-01-01 00:00:00 Sending Order: ASIANPAINT | Month 1 | Rebalanced: False | Pos: 81
# 2020-01-01 00:00:00 Sending Order: AXISBANK | Month 1 | Rebalanced: False | Pos: 163
# 2020-01-01 00:00:00 Sending Order: BAJFINANCE | Month 1 | Rebalanced: False | Pos: 35
# 2020-01-01 00:00:00 Sending Order: BHARTIARTL | Month 1 | Rebalanced: False | Pos: 364
# 2020-01-01 00:00:00 Sending Order: HCLTECH | Month 1 | Rebalanced: False | Pos: 227
# 2020-01-01 00:00:00 Sending Order: HDFC | Month 1 | Rebalanced: False | Pos: 56
# 2020-01-01 00:00:00 Sending Order: HDFCBANK | Month 1 | Rebalanced: False | Pos: 108
# 2020-01-01 00:00:00 Sending Order: HINDUNILVR | Month 1 | Rebalanced: False | Pos: 71
# 2020-01-01 00:00:00 Sending Order: ICICIBANK | Month 1 | Rebalanced: False | Pos: 272
# 2020-01-01 00:00:00 Sending Order: INFY | Month 1 | Rebalanced: False | Pos: 160
# 2020-01-01 00:00:00 Sending Order: ITC | Month 1 | Rebalanced: False | Pos: 528
# 2020-01-01 00:00:00 Sending Order: KOTAKBANK | Month 1 | Rebalanced: False | Pos: 82
# 2020-01-01 00:00:00 Sending Order: LT | Month 1 | Rebalanced: False | Pos: 90
# 2020-01-01 00:00:00 Sending Order: MARUTI | Month 1 | Rebalanced: False | Pos: 19
# 2020-01-01 00:00:00 Sending Order: NESTLEIND | Month 1 | Rebalanced: False | Pos: 8
# 2020-01-01 00:00:00 Sending Order: RELIANCE | Month 1 | Rebalanced: False | Pos: 98
# 2020-01-01 00:00:00 Sending Order: SBIN | Month 1 | Rebalanced: False | Pos: 328
# 2020-01-01 00:00:00 Sending Order: SUNPHARMA | Month 1 | Rebalanced: False | Pos: 293
# 2020-01-01 00:00:00 Sending Order: TCS | Month 1 | Rebalanced: False | Pos: 59
# 2020-01-01 00:00:00 Sending Order: WIPRO | Month 1 | Rebalanced: False | Pos: 504
# 2020-01-02 >> Order Completed >> Stock: ASIANPAINT,  Ref: 696, Size: -1, Price: 1786.02441
# 2020-01-02 >> Order Completed >> Stock: AXISBANK,  Ref: 697, Size: -4, Price: 748.70001
# 2020-01-02 >> Order Completed >> Stock: BAJFINANCE,  Ref: 698, Size: -5, Price: 4221.59668
# 2020-01-02 >> Order Completed >> Stock: BHARTIARTL,  Ref: 699, Size: -59, Price: 453.29999
# 2020-01-02 >> Order Completed >> Stock: HCLTECH,  Ref: 700, Size: 19, Price: 570.04016
# 2020-01-02 >> Order Completed >> Stock: HDFC,  Ref: 701, Size: -2, Price: 2433.95
# 2020-01-02 >> Order Completed >> Stock: HDFCBANK,  Ref: 702, Size: -1, Price: 1278.59998
# 2020-01-02 >> Order Completed >> Stock: HINDUNILVR,  Ref: 703, Size: 4, Price: 1936.55005
# 2020-01-02 >> Order Completed >> Stock: ICICIBANK,  Ref: 704, Size: -47, Price: 536.75
# 2020-01-02 >> Order Completed >> Stock: INFY,  Ref: 705, Size: 34, Price: 726.95447
# 2020-01-02 >> Order Completed >> Stock: ITC,  Ref: 706, Size: 75, Price: 238.10001
# 2020-01-02 >> Order Completed >> Stock: KOTAKBANK,  Ref: 707, Size: -3, Price: 1674.05005
# 2020-01-02 >> Order Completed >> Stock: LT,  Ref: 708, Size: 10, Price: 1291.85791
# 2020-01-02 >> Order Completed >> Stock: NESTLEIND,  Ref: 709, Size: -1, Price: 14614.98633
# 2020-01-02 >> Order Completed >> Stock: RELIANCE,  Ref: 710, Size: -9, Price: 1509.59998
# 2020-01-02 >> Order Completed >> Stock: SBIN,  Ref: 711, Size: 41, Price: 334.45001
# 2020-01-02 >> Order Completed >> Stock: SUNPHARMA,  Ref: 712, Size: 40, Price: 431.1871
# 2020-01-02 >> Order Completed >> Stock: TCS,  Ref: 713, Size: 7, Price: 2140.70972
# 2020-03-02 00:00:00 Sending Order: ASIANPAINT | Month 3 | Rebalanced: False | Pos: 80
# 2020-03-02 00:00:00 Sending Order: AXISBANK | Month 3 | Rebalanced: False | Pos: 159
# 2020-03-02 00:00:00 Sending Order: BAJFINANCE | Month 3 | Rebalanced: False | Pos: 30
# 2020-03-02 00:00:00 Sending Order: BHARTIARTL | Month 3 | Rebalanced: False | Pos: 305
# 2020-03-02 00:00:00 Sending Order: HCLTECH | Month 3 | Rebalanced: False | Pos: 246
# 2020-03-02 00:00:00 Sending Order: HDFC | Month 3 | Rebalanced: False | Pos: 54
# 2020-03-02 00:00:00 Sending Order: HDFCBANK | Month 3 | Rebalanced: False | Pos: 107
# 2020-03-02 00:00:00 Sending Order: HINDUNILVR | Month 3 | Rebalanced: False | Pos: 75
# 2020-03-02 00:00:00 Sending Order: ICICIBANK | Month 3 | Rebalanced: False | Pos: 225
# 2020-03-02 00:00:00 Sending Order: INFY | Month 3 | Rebalanced: False | Pos: 194
# 2020-03-02 00:00:00 Sending Order: ITC | Month 3 | Rebalanced: False | Pos: 603
# 2020-03-02 00:00:00 Sending Order: KOTAKBANK | Month 3 | Rebalanced: False | Pos: 79
# 2020-03-02 00:00:00 Sending Order: LT | Month 3 | Rebalanced: False | Pos: 100
# 2020-03-02 00:00:00 Sending Order: MARUTI | Month 3 | Rebalanced: False | Pos: 19
# 2020-03-02 00:00:00 Sending Order: NESTLEIND | Month 3 | Rebalanced: False | Pos: 7
# 2020-03-02 00:00:00 Sending Order: RELIANCE | Month 3 | Rebalanced: False | Pos: 89
# 2020-03-02 00:00:00 Sending Order: SBIN | Month 3 | Rebalanced: False | Pos: 369
# 2020-03-02 00:00:00 Sending Order: SUNPHARMA | Month 3 | Rebalanced: False | Pos: 333
# 2020-03-02 00:00:00 Sending Order: TCS | Month 3 | Rebalanced: False | Pos: 66
# 2020-03-02 00:00:00 Sending Order: WIPRO | Month 3 | Rebalanced: False | Pos: 504
# 2020-03-03 >> Order Completed >> Stock: ASIANPAINT,  Ref: 715, Size: -4, Price: 1779.65002
# 2020-03-03 >> Order Completed >> Stock: AXISBANK,  Ref: 716, Size: 4, Price: 684.20001
# 2020-03-03 >> Order Completed >> Stock: BAJFINANCE,  Ref: 717, Size: -2, Price: 4350.75
# 2020-03-03 >> Order Completed >> Stock: BHARTIARTL,  Ref: 718, Size: -53, Price: 518.34998
# 2020-03-03 >> Order Completed >> Stock: HCLTECH,  Ref: 719, Size: -4, Price: 549.70001
# 2020-03-03 >> Order Completed >> Stock: HDFC,  Ref: 720, Size: 2, Price: 2179.65
# 2020-03-03 >> Order Completed >> Stock: HDFCBANK,  Ref: 721, Size: 1, Price: 1179.59998
# 2020-03-03 >> Order Completed >> Stock: HINDUNILVR,  Ref: 722, Size: -11, Price: 2159.44995
# 2020-03-03 >> Order Completed >> Stock: INFY,  Ref: 723, Size: -11, Price: 731.09808
# 2020-03-03 >> Order Completed >> Stock: ITC,  Ref: 724, Size: 93, Price: 195.3
# 2020-03-03 >> Order Completed >> Stock: KOTAKBANK,  Ref: 725, Size: -1, Price: 1599.0
# 2020-03-03 >> Order Completed >> Stock: LT,  Ref: 726, Size: 7, Price: 1144.86658
# 2020-03-03 >> Order Completed >> Stock: MARUTI,  Ref: 727, Size: 1, Price: 6285.1499
# 2020-03-03 >> Order Completed >> Stock: NESTLEIND,  Ref: 728, Size: -1, Price: 15931.21484
# 2020-03-03 >> Order Completed >> Stock: RELIANCE,  Ref: 729, Size: 6, Price: 1316.15002
# 2020-03-03 >> Order Completed >> Stock: SBIN,  Ref: 730, Size: 37, Price: 287.39999
# 2020-03-03 >> Order Completed >> Stock: SUNPHARMA,  Ref: 731, Size: 35, Price: 369.5
# 2020-03-03 >> Order Completed >> Stock: TCS,  Ref: 732, Size: 2, Price: 1980.96082
# Final Portfolio Value: 2240649.51

# %%
# Extract inputs for pyfolio
strat = results[0]
pyfoliozer = strat.analyzers.getbyname('pyfolio')

# %%
# Extract inputs for pyfolio
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
returns.name = 'Strategy'
returns.head(2)
# Out:
# index
# 2010-01-04 00:00:00+00:00    0.000000
# 2010-01-05 00:00:00+00:00   -0.307223
# Name: Strategy, dtype: float64

# %%
# Get the benchmark returns for comparison
benchmark = '^BSESN' # S&P BSE Sensex
benchmark_rets= web.DataReader(benchmark, 'yahoo', start='2010-01-01',)['Adj Close'].pct_change().dropna()
benchmark_rets.index = benchmark_rets.index.tz_localize('UTC') 
benchmark_rets = benchmark_rets.filter(returns.index)
benchmark_rets.name = 'S&P BSE-SENSEX'
benchmark_rets.head(2)
# Out:
# Date
# 2010-01-05 00:00:00+00:00    0.007262
# 2010-01-06 00:00:00+00:00    0.000842
# Name: S&P BSE-SENSEX, dtype: float64

# %%
# Get the benchmark prices for comparison
benchmark = '^BSESN' # S&P BSE Sensex
benchmark_prices = web.DataReader(benchmark, 'yahoo', start='2010-01-01',)['Adj Close']
benchmark_prices = benchmark_prices.asfreq('D', method='ffill')
benchmark_prices.index = benchmark_prices.index.tz_localize('UTC')
benchmark_prices = benchmark_prices.filter(returns.index)
benchmark_prices.head(5)
# Out:
# Date
# 2010-01-04 00:00:00+00:00    17558.730469
# 2010-01-05 00:00:00+00:00    17686.240234
# 2010-01-06 00:00:00+00:00    17701.130859
# 2010-01-07 00:00:00+00:00    17615.720703
# 2010-01-08 00:00:00+00:00    17540.289062
# Name: Adj Close, dtype: float64

# %%
# Rebase the benchmark prices for comparison
benchmark_prices = (benchmark_prices/benchmark_prices.iloc[0]) * startcash
benchmark_prices.head()
# Out:
# Date
# 2010-01-04 00:00:00+00:00    500000.000000
# 2010-01-05 00:00:00+00:00    503630.950593
# 2010-01-06 00:00:00+00:00    504054.973988
# 2010-01-07 00:00:00+00:00    501622.846096
# 2010-01-08 00:00:00+00:00    499474.865046
# Name: Adj Close, dtype: float64

# %%
portfolio_value = returns.cumsum().apply(np.exp) * startcash

# Visulize the output
fig, ax = plt.subplots(2, 1, sharex=True, figsize=[14, 8])

# portfolio value
portfolio_value.plot(ax=ax[0], label='Strategy')
benchmark_prices.plot(ax=ax[0], label='Benchmark - S&P BSE-Sensex')
ax[0].set_ylabel('Portfolio Value')
ax[0].grid(True)
ax[0].legend()

# daily returns
returns.plot(ax=ax[1], label='Strategy', alpha=0.5)
benchmark_rets.plot(ax=ax[1], label='Benchmark - S&P BSE-Sensex', alpha=0.5)
ax[1].set_ylabel('Daily Returns')

fig.suptitle('Black–Litterman Portfolio Allocation vs S&P BSE-Sensex', fontsize=16)
plt.grid(True)
plt.legend()
plt.show()
fig.savefig('images/chart9', dpi=300)

# %%
import seaborn as sns
import warnings
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
warnings.filterwarnings('ignore')

# %%
# get performance statistics for strategy
pf.show_perf_stats(returns,)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-05-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>122</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>15.771%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>348.13%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.78%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.97</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-36.19%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-7.28</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>184.84</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# get performance statistics for benchmark
pf.show_perf_stats(benchmark_rets)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-05-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>121</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.246%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>84.661%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>17.474%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.43</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.16</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-38.07%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.08</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.76</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>14.36</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.171%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# plot performance for strategy
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(14, 8),constrained_layout=True)
axes = ax.flatten()

pf.plot_drawdown_periods(returns=returns, ax=axes[0])
axes[0].grid(True)
pf.plot_rolling_returns(returns=returns,
                        factor_returns=benchmark_rets,
                        ax=axes[1], title='Strategy vs BSE-SENSEX')
axes[1].grid(True)
pf.plot_drawdown_underwater(returns=returns, ax=axes[2])
axes[2].grid(True)
pf.plot_rolling_sharpe(returns=returns, ax=axes[3])
axes[3].grid(True)
fig.suptitle('BL Portfolio vs BSE-SENSEX - 1', fontsize=12, y=0.990)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('images/chart7', dpi=300)

# %%
# plot performance
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(16, 9),constrained_layout=True)
axes = ax.flatten()

pf.plot_rolling_beta(returns=returns, factor_returns=benchmark_rets, ax=axes[0])
axes[0].grid(True)

pf.plot_rolling_volatility(returns=returns, factor_returns=benchmark_rets,ax=axes[1])
axes[1].grid(True)

pf.plot_annual_returns(returns=returns, ax=axes[2])
axes[2].grid(True)

pf.plot_monthly_returns_heatmap(returns=returns, ax=axes[3],)
fig.suptitle('BL Portfolio vs BSE-SENSEX - 2', fontsize=16, y=1.0)


plt.tight_layout()
plt.savefig('images/chart8', dpi=300)
